# %%
import networkx as nx
import pandas as pd
import numpy as np  


def get_price(dist):
    return np.random.normal(0.20, 0.07) * dist

def add_edge(graph, row):
    departure_time = {'YEAR': row['YEAR'], 'MONTH': row['MONTH'], 'DAY': row['DAY'], 'TIME': row['SCHEDULED_DEPARTURE']}
    arrival_time = {'YEAR': row['YEAR'], 'MONTH': row['MONTH'], 'DAY': row['DAY'], 'TIME': row['SCHEDULED_ARRIVAL']}
    graph.add_edge(row['ORIGIN_AIRPORT'], row['DESTINATION_AIRPORT'], departure_time=departure_time, arrival_time=arrival_time, flight_time=row['SCHEDULED_TIME'], price=row['price'])

COLS = ['YEAR', 'MONTH', 'DAY', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT', 'SCHEDULED_DEPARTURE', 'DISTANCE', 'SCHEDULED_TIME', 'SCHEDULED_ARRIVAL']
N = 100000 #max = 5819079

flights = pd.read_csv("Flights-BO/data/flights.csv")[COLS]
flights = flights.head(N)
flights = flights[flights['SCHEDULED_TIME'].notna()]
flights['PRICE'] = flights['DISTANCE'].apply(lambda x: get_price(x))
print(flights.head(5))

MG = nx.MultiGraph()

for idx, row in flights.iterrows():
    departure_time = {'YEAR': row['YEAR'], 'MONTH': row['MONTH'], 'DAY': row['DAY'], 'TIME': row['SCHEDULED_DEPARTURE']}
    arrival_time = {'YEAR': row['YEAR'], 'MONTH': row['MONTH'], 'DAY': row['DAY'], 'TIME': row['SCHEDULED_ARRIVAL']}
    # print(row['ORIGIN_AIRPORT'], row['DESTINATION_AIRPORT'], departure_time, arrival_time, row['SCHEDULED_TIME'], row['PRICE'])
    MG.add_edge(row['ORIGIN_AIRPORT'], row['DESTINATION_AIRPORT'], departure_time=departure_time, arrival_time=arrival_time, flight_time=row['SCHEDULED_TIME'], price=row['PRICE'])
# Out:
# C:\Users\Robert\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    YEAR  MONTH  DAY ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  \
# 0  2015      1    1            ANC                 SEA                    5
# 1  2015      1    1            LAX                 PBI                   10
# 2  2015      1    1            SFO                 CLT                   20
# 3  2015      1    1            LAX                 MIA                   20
# 4  2015      1    1            SEA                 ANC                   25
#
#    DISTANCE  SCHEDULED_TIME  SCHEDULED_ARRIVAL       PRICE
# 0      1448           205.0                430  248.275527
# 1      2330           280.0                750  268.136599
# 2      2296           286.0                806  352.760791
# 3      2342           285.0                805  457.329843
# 4      1448           235.0                320  142.766391

# %%
import queue
import datetime
import time
import random

# %%
def parse_date(date):
    if str(type(date)) == '<class \'datetime.datetime\'>':
        return date
    return datetime.datetime(date['YEAR'], date['MONTH'], date['DAY'], int('{:04d}'.format(date['TIME'])[:2]), int('{:04d}'.format(date['TIME'])[2:]))

for airport_1 in MG.nodes:  
    for airport_2 in MG.adj[airport_1]:
        if airport_1 != airport_2:
            for flight in MG.adj[airport_1][airport_2]:
                MG.adj[airport_1][airport_2][flight]['departure_time'] = parse_date(MG.adj[airport_1][airport_2][flight]['departure_time'])
                MG.adj[airport_1][airport_2][flight]['arrival_time'] = parse_date(MG.adj[airport_1][airport_2][flight]['arrival_time'])
                MG.adj[airport_1][airport_2][flight]['pheromone_level'] = 0
                MG.adj[airport_1][airport_2][flight]['pheromone_update_time'] = 0

# %%
# print(len(MG.nodes))

# for airport_name in MG.nodes:
#     print(airport_name, len(MG.adj['LAS'][airport_name]) if airport_name in MG.adj['LAS'] else 0)
    
    
# for flight in MG.adj['LAS']:
#     print(MG.adj['LAS'][flight])
#     print('\n\n\n')
    
# print(MG.adj['LAS']['HNL'])    
    
# for i in range(0, len(MG.adj['LAS']['HNL'])):
#     print(MG.adj['LAS']['HNL'][i-1]['departure_time'])

# %%
ANTS_NUMBER = 1000
ANTS_SPAWN_ITERS = 10
SIMULATION_TIME_S = 20
SIMULATION_ITERS_NUM = 100000

# %%
class Ant:
    def __init__(self, curr_time, curr_airport):
        self.curr_time = curr_time
        self.curr_airport = curr_airport
        self.birth_time = curr_time
        
        self.curr_trav_cost = 0
        self.curr_conn_numb = 0
        self.mode = 0
        self.path = [curr_airport]
        
    def __lt__ (self, other):
        if self.mode != other.mode:
            return self.mode < other.mode
        return self.curr_time < other.curr_time
        
    def __gt__ (self, other):
        if self.mode != other.mode:
            return self.mode > other.mode
        return self.curr_time > other.curr_time

    def __eq__ (self, other):
        return self.mode == other.mode and self.curr_time == other.curr_time

    def __ne__ (self, other):
        return not self.__eq__(other)
    
    def _print_ant(self):
        print(f'\ntravel cost {self.curr_trav_cost}\nconnections number {self.curr_conn_numb}\nflights {self.path}\n')
        
    def _update(self, next_flight):
        self.curr_time = next_flight[2]['arrival_time']
        self.curr_airport = next_flight[0]
        self.curr_trav_cost += next_flight[2]['price']
        self.curr_conn_numb += 1
        self.path.append((next_flight[0], next_flight[2]['departure_time'], next_flight[2]['arrival_time']))

# %%
class AntColonyAlgorithm:
    def __init__(self, flights, origin, destination, min_time, max_time, min_conn_time, max_conn_numb, max_price):
        self.flights = flights
        self.origin = origin
        self.destionation = destination
        self.min_time = min_time
        self.max_time = max_time
        self.min_conn_time = min_conn_time
        self.max_conn_numb = max_conn_numb
        self.max_price = max_price

        self.global_time = 0
        self.events = queue.PriorityQueue()

    def _init_ants(self):
        time_available_min = (self.max_time - self.min_time).total_seconds() // 60

        ants_spawn_gap = time_available_min // ANTS_SPAWN_ITERS
        for i in range(ANTS_SPAWN_ITERS):
            for j in range(ANTS_NUMBER // ANTS_SPAWN_ITERS):
                self.events.put((i * ants_spawn_gap, Ant(self.min_time + datetime.timedelta(minutes=i * ants_spawn_gap), self.origin)))
                
    def _run_next_event(self):
        curr_time, curr_ant = self.events.get()[0], self.events.get()[1]
        available_flights = self._find_available_flights(curr_time, curr_ant)
        next_flight = self._choose_flight(available_flights, curr_ant)
        if next_flight == None:
            self._kill_ant(curr_ant)
        else:
            time_diff = (next_flight[2]['arrival_time'] - curr_ant.curr_time).total_seconds() // 60
            new_time = curr_time + time_diff
            
            curr_ant._update(next_flight) 
            if next_flight[0] == self.destionation:
                curr_ant._print_ant()
            else:
                self.events.put((new_time, curr_ant))
        
    def _find_available_flights(self, curr_time, curr_ant): #change to binary search
        all_flights = self.flights[curr_ant.curr_airport]
        available_flights = []
        for airport in all_flights:
            for flight_idx in range(len(self.flights.adj[curr_ant.curr_airport][airport])):
                flight = self.flights.adj[curr_ant.curr_airport][airport][flight_idx]
                if curr_ant.curr_time + datetime.timedelta(minutes=self.min_conn_time) < flight['departure_time']:
                    available_flights.append((airport, flight_idx, flight))
                    break
        return available_flights
    
    def _choose_flight(self, available_flights, curr_ant):
        available_flights_copy = []
        for (airport, index, flight) in available_flights:
            if airport == self.destionation:
                return (airport, index, flight)
            if flight['arrival_time'] < self.max_time:
                available_flights_copy.append((airport, index, flight))
    
        if len(available_flights_copy) == 0:
            return None
        return available_flights_copy[random.randint(0, len(available_flights_copy)-1)]
                
    def _kill_ant(self, curr_ant): #todo - spawning new ant
        print(f'ant dies :c', curr_ant._print_ant())

    def run(self):
        self._init_ants()
        
#         while not self.events.empty():
#             print(self.events.get())  
        
#         start_time = time.time()
#         counter = 0
#         while not self.events.empty() and (counter % 100 != 0 or time.time() - start_time < SIMULATION_TIME_S):
#             self._run_next_event()
#             counter += 1
            
        counter = 0
        while not self.events.empty() and counter < SIMULATION_ITERS_NUM:
            self._run_next_event()
            counter += 1
    
            
        



simulation = AntColonyAlgorithm(MG, 'LAS', 'JAX', datetime.datetime(2015, 1, 1, 8, 0, 0), datetime.datetime(2015, 1, 8, 8, 0, 0), 90, 5, 5000)
simulation.run()
# Out:
# travel cost 710.2334590125311
# connections number 2
# flights ['LAS', ('BWI', datetime.datetime(2015, 1, 1, 10, 0), datetime.datetime(2015, 1, 1, 12, 30)), ('JAX', datetime.datetime(2015, 1, 1, 15, 50), datetime.datetime(2015, 1, 1, 17, 55))]
#
#
# travel cost 655.7799408932322
# connections number 2
# flights ['LAS', ('DTW', datetime.datetime(2015, 1, 1, 11, 17), datetime.datetime(2015, 1, 1, 12, 46)), ('JAX', datetime.datetime(2015, 1, 3, 10, 45), datetime.datetime(2015, 1, 3, 13, 10))]
#
#
# travel cost 661.3657323329027
# connections number 2
# flights ['LAS', ('MSP', datetime.datetime(2015, 1, 1, 14, 55), datetime.datetime(2015, 1, 1, 16, 18)), ('JAX', datetime.datetime(2015, 1, 2, 8, 10), datetime.datetime(2015, 1, 2, 10, 23))]
#
#
# travel cost 417.8855542707707
# connections number 3
# flights ['LAS', ('AMA', datetime.datetime(2015, 1, 1, 13, 45), datetime.datetime(2015, 1, 1, 13, 55)), ('IAH', datetime.datetime(2015, 1, 1, 16, 43), datetime.datetime(2015, 1, 1, 18, 20)), ('JAX', datetime.datetime(2015, 1, 2, 6, 30), datetime.datetime(2015, 1, 2, 8, 5))]
#
#
# travel cost 538.1019173530566
# connections number 2
# flights ['LAS', ('PHL', datetime.datetime(2015, 1, 1, 11, 30), datetime.datetime(2015, 1, 1, 19, 7)), ('JAX', datetime.datetime(2015, 1, 2, 6, 45), datetime.datetime(2015, 1, 2, 8, 48))]
#
#
# travel cost 409.9587273317076
# connections number 3
# flights ['LAS', ('TUL', datetime.datetime(2015, 1, 1, 13, 15), datetime.datetime(2015, 1, 1, 14, 15)), ('MDW', datetime.datetime(2015, 1, 1, 17, 45), datetime.datetime(2015, 1, 1, 19, 40)), ('JAX', datetime.datetime(2015, 1, 2, 14, 0), datetime.datetime(2015, 1, 2, 17, 10))]
#
#
# travel cost 618.7385625758864
# connections number 4
# flights ['LAS', ('LGB', datetime.datetime(2015, 1, 1, 11, 0), datetime.datetime(2015, 1, 1, 12, 4)), ('SEA', datetime.datetime(2015, 1, 1, 14, 0), datetime.datetime(2015, 1, 1, 16, 43)), ('BOS', datetime.datetime(2015, 1, 1, 18, 40), datetime.datetime(2015, 1, 1, 22, 15)), ('JAX', datetime.datetime(2015, 1, 2, 7, 0), datetime.datetime(2015, 1, 2, 10, 8))]
#
#
# travel cost 505.3002315916146
# connections number 2
# flights ['LAS', ('FLL', datetime.datetime(2015, 1, 1, 15, 20), datetime.datetime(2015, 1, 1, 22, 50)), ('JAX', datetime.datetime(2015, 1, 2, 7, 5), datetime.datetime(2015, 1, 2, 8, 23))]
#
#
# travel cost 626.8822305079568
# connections number 2
# flights ['LAS', ('MSP', datetime.datetime(2015, 1, 2, 6, 55), datetime.datetime(2015, 1, 2, 8, 33)), ('JAX', datetime.datetime(2015, 1, 2, 19, 40), datetime.datetime(2015, 1, 2, 23, 36))]
#
#
# travel cost 607.8627927387269
# connections number 2
# flights ['LAS', ('PHL', datetime.datetime(2015, 1, 2, 6, 55), datetime.datetime(2015, 1, 2, 9, 40)), ('JAX', datetime.datetime(2015, 1, 2, 18, 5), datetime.datetime(2015, 1, 2, 20, 32))]
#
#
# travel cost 564.3182833042199
# connections number 2
# flights ['LAS', ('DCA', datetime.datetime(2015, 1, 2, 8, 25), datetime.datetime(2015, 1, 2, 10, 55)), ('JAX', datetime.datetime(2015, 1, 2, 13, 15), datetime.datetime(2015, 1, 2, 14, 59))]
#
#
# travel cost 780.6048687151525
# connections number 2
# flights ['LAS', ('BOS', datetime.datetime(2015, 1, 2, 8, 30), datetime.datetime(2015, 1, 2, 11, 39)), ('JAX', datetime.datetime(2015, 1, 2, 13, 45), datetime.datetime(2015, 1, 2, 16, 47))]
#
#
# travel cost 755.4358983048992
# connections number 4
# flights ['LAS', ('TPA', datetime.datetime(2015, 1, 1, 9, 40), datetime.datetime(2015, 1, 1, 16, 50)), ('SDF', datetime.datetime(2015, 1, 1, 18, 50), datetime.datetime(2015, 1, 1, 20, 55)), ('ORD', datetime.datetime(2015, 1, 2, 10, 37), datetime.datetime(2015, 1, 2, 12, 59)), ('JAX', datetime.datetime(2015, 1, 3, 7, 51), datetime.datetime(2015, 1, 3, 11, 14))]
#
#
# travel cost 444.50275969686777
# connections number 2
# flights ['LAS', ('ATL', datetime.datetime(2015, 1, 2, 6, 0), datetime.datetime(2015, 1, 2, 12, 41)), ('JAX', datetime.datetime(2015, 1, 2, 14, 15), datetime.datetime(2015, 1, 2, 15, 31))]
#
#
# travel cost 616.0615311213552
# connections number 3
# flights ['LAS', ('PIT', datetime.datetime(2015, 1, 2, 8, 0), datetime.datetime(2015, 1, 2, 10, 10)), ('IAD', datetime.datetime(2015, 1, 2, 12, 46), datetime.datetime(2015, 1, 2, 13, 47)), ('JAX', datetime.datetime(2015, 1, 3, 8, 24), datetime.datetime(2015, 1, 3, 10, 32))]
#
#
# travel cost 648.8488801668198
# connections number 3
# flights ['LAS', ('AUS', datetime.datetime(2015, 1, 2, 6, 0), datetime.datetime(2015, 1, 2, 7, 5)), ('BWI', datetime.datetime(2015, 1, 2, 14, 40), datetime.datetime(2015, 1, 2, 18, 40)), ('JAX', datetime.datetime(2015, 1, 2, 20, 20), datetime.datetime(2015, 1, 2, 22, 25))]
#
#
# travel cost 1659.0406174654397
# connections number 4
# flights ['LAS', ('RDU', datetime.datetime(2015, 1, 2, 6, 0), datetime.datetime(2015, 1, 2, 8, 20)), ('PHX', datetime.datetime(2015, 1, 2, 10, 5), datetime.datetime(2015, 1, 2, 16, 0)), ('MDW', datetime.datetime(2015, 1, 2, 17, 40), datetime.datetime(2015, 1, 2, 20, 35)), ('JAX', datetime.datetime(2015, 1, 3, 14, 0), datetime.datetime(2015, 1, 3, 17, 10))]
#
#
# travel cost 469.02047818006815
# connections number 2
# flights ['LAS', ('IAH', datetime.datetime(2015, 1, 2, 19, 11), datetime.datetime(2015, 1, 2, 20, 38)), ('JAX', datetime.datetime(2015, 1, 3, 6, 30), datetime.datetime(2015, 1, 3, 8, 5))]
#
#
# travel cost 558.7229013887626
# connections number 2
# flights ['LAS', ('DTW', datetime.datetime(2015, 1, 2, 19, 45), datetime.datetime(2015, 1, 2, 21, 12)), ('JAX', datetime.datetime(2015, 1, 3, 10, 45), datetime.datetime(2015, 1, 3, 13, 10))]
#
#
# travel cost 633.7427654489112
# connections number 3
# flights ['LAS', ('TUS', datetime.datetime(2015, 1, 2, 7, 0), datetime.datetime(2015, 1, 2, 7, 15)), ('MDW', datetime.datetime(2015, 1, 2, 19, 20), datetime.datetime(2015, 1, 2, 22, 15)), ('JAX', datetime.datetime(2015, 1, 3, 14, 0), datetime.datetime(2015, 1, 3, 17, 10))]
#
#
# travel cost 709.1589290208141
# connections number 2
# flights ['LAS', ('FLL', datetime.datetime(2015, 1, 2, 20, 9), datetime.datetime(2015, 1, 2, 22, 41)), ('JAX', datetime.datetime(2015, 1, 3, 7, 5), datetime.datetime(2015, 1, 3, 8, 23))]
#
#
# travel cost 344.69194613257287
# connections number 2
# flights ['LAS', ('BOS', datetime.datetime(2015, 1, 2, 20, 5), datetime.datetime(2015, 1, 2, 23, 8)), ('JAX', datetime.datetime(2015, 1, 3, 7, 0), datetime.datetime(2015, 1, 3, 10, 8))]
#
#
# travel cost 595.4961562322933
# connections number 3
# flights ['LAS', ('SAT', datetime.datetime(2015, 1, 2, 19, 40), datetime.datetime(2015, 1, 2, 20, 40)), ('ATL', datetime.datetime(2015, 1, 3, 6, 0), datetime.datetime(2015, 1, 3, 9, 10)), ('JAX', datetime.datetime(2015, 1, 3, 11, 5), datetime.datetime(2015, 1, 3, 12, 15))]
#
#
# travel cost 516.5089749791227
# connections number 2
# flights ['LAS', ('BNA', datetime.datetime(2015, 1, 3, 7, 15), datetime.datetime(2015, 1, 3, 9, 35)), ('JAX', datetime.datetime(2015, 1, 3, 11, 35), datetime.datetime(2015, 1, 3, 12, 5))]
#
#
# travel cost 657.9949207123632
# connections number 3
# flights ['LAS', ('LIT', datetime.datetime(2015, 1, 2, 14, 5), datetime.datetime(2015, 1, 2, 15, 35)), ('MDW', datetime.datetime(2015, 1, 3, 10, 10), datetime.datetime(2015, 1, 3, 11, 50)), ('JAX', datetime.datetime(2015, 1, 3, 14, 0), datetime.datetime(2015, 1, 3, 17, 10))]
#
#
# travel cost 1696.95487781586
# connections number 6
# flights ['LAS', ('MCO', datetime.datetime(2015, 1, 2, 7, 5), datetime.datetime(2015, 1, 2, 9, 20)), ('ACY', datetime.datetime(2015, 1, 2, 11, 30), datetime.datetime(2015, 1, 2, 13, 58)), ('TPA', datetime.datetime(2015, 1, 2, 17, 0), datetime.datetime(2015, 1, 2, 19, 13)), ('SJU', datetime.datetime(2015, 1, 2, 20, 59), datetime.datetime(2015, 1, 2, 23, 7)), ('PHL', datetime.datetime(2015, 1, 3, 7, 35), datetime.datetime(2015, 1, 3, 12, 22)), ('JAX', datetime.datetime(2015, 1, 4, 7, 50), datetime.datetime(2015, 1, 4, 10, 15))]
#
#
# travel cost 403.51695094447314
# connections number 2
# flights ['LAS', ('DTW', datetime.datetime(2015, 1, 3, 12, 0), datetime.datetime(2015, 1, 3, 13, 34)), ('JAX', datetime.datetime(2015, 1, 5, 12, 24), datetime.datetime(2015, 1, 5, 14, 50))]
#
#
# travel cost 233.10072910257333
# connections number 2
# flights ['LAS', ('ATL', datetime.datetime(2015, 1, 3, 13, 38), datetime.datetime(2015, 1, 3, 15, 14)), ('JAX', datetime.datetime(2015, 1, 3, 16, 45), datetime.datetime(2015, 1, 3, 17, 54))]
#
#
# travel cost 618.3482502283634
# connections number 2
# flights ['LAS', ('BWI', datetime.datetime(2015, 1, 3, 13, 15), datetime.datetime(2015, 1, 3, 15, 45)), ('JAX', datetime.datetime(2015, 1, 3, 19, 5), datetime.datetime(2015, 1, 3, 20, 55))]
#
#
# travel cost 1157.762442794873
# connections number 5
# flights ['LAS', ('MIA', datetime.datetime(2015, 1, 2, 19, 55), datetime.datetime(2015, 1, 2, 22, 25)), ('LAS', datetime.datetime(2015, 1, 3, 0, 35), datetime.datetime(2015, 1, 3, 8, 3)), ('BHM', datetime.datetime(2015, 1, 3, 10, 5), datetime.datetime(2015, 1, 3, 12, 25)), ('DFW', datetime.datetime(2015, 1, 3, 14, 55), datetime.datetime(2015, 1, 3, 16, 30)), ('JAX', datetime.datetime(2015, 1, 3, 18, 45), datetime.datetime(2015, 1, 3, 21, 55))]
#
#
# travel cost 387.9348370255043
# connections number 2
# flights ['LAS', ('DFW', datetime.datetime(2015, 1, 3, 12, 10), datetime.datetime(2015, 1, 3, 16, 50)), ('JAX', datetime.datetime(2015, 1, 3, 18, 45), datetime.datetime(2015, 1, 3, 21, 55))]
#
#
# travel cost 387.9348370255043
# connections number 2
# flights ['LAS', ('DFW', datetime.datetime(2015, 1, 3, 12, 10), datetime.datetime(2015, 1, 3, 16, 50)), ('JAX', datetime.datetime(2015, 1, 3, 18, 45), datetime.datetime(2015, 1, 3, 21, 55))]
#
#
# travel cost 368.6605857480542
# connections number 2
# flights ['LAS', ('MDW', datetime.datetime(2015, 1, 3, 12, 0), datetime.datetime(2015, 1, 3, 17, 30)), ('JAX', datetime.datetime(2015, 1, 4, 14, 0), datetime.datetime(2015, 1, 4, 17, 10))]
#
#
# travel cost 274.93502908855885
# connections number 3
# flights ['LAS', ('AMA', datetime.datetime(2015, 1, 3, 9, 25), datetime.datetime(2015, 1, 3, 13, 20)), ('IAH', datetime.datetime(2015, 1, 3, 16, 43), datetime.datetime(2015, 1, 3, 18, 20)), ('JAX', datetime.datetime(2015, 1, 4, 6, 30), datetime.datetime(2015, 1, 4, 8, 5))]
#
#
# travel cost 369.10277579090837
# connections number 2
# flights ['LAS', ('MSP', datetime.datetime(2015, 1, 3, 13, 33), datetime.datetime(2015, 1, 3, 18, 45)), ('JAX', datetime.datetime(2015, 1, 4, 8, 10), datetime.datetime(2015, 1, 4, 10, 22))]
#
#
# travel cost 369.10277579090837
# connections number 2
# flights ['LAS', ('MSP', datetime.datetime(2015, 1, 3, 13, 33), datetime.datetime(2015, 1, 3, 18, 45)), ('JAX', datetime.datetime(2015, 1, 4, 8, 10), datetime.datetime(2015, 1, 4, 10, 22))]
#
#
# travel cost 509.2097854916305
# connections number 3
# flights ['LAS', ('FNT', datetime.datetime(2015, 1, 3, 15, 0), datetime.datetime(2015, 1, 3, 16, 30)), ('ORD', datetime.datetime(2015, 1, 3, 18, 55), datetime.datetime(2015, 1, 3, 19, 2)), ('JAX', datetime.datetime(2015, 1, 4, 7, 51), datetime.datetime(2015, 1, 4, 11, 14))]
#
#
# travel cost 631.195345079274
# connections number 3
# flights ['LAS', ('TPA', datetime.datetime(2015, 1, 3, 9, 40), datetime.datetime(2015, 1, 3, 16, 50)), ('HOU', datetime.datetime(2015, 1, 3, 19, 35), datetime.datetime(2015, 1, 3, 21, 0)), ('JAX', datetime.datetime(2015, 1, 4, 19, 25), datetime.datetime(2015, 1, 4, 21, 0))]
#
#
# travel cost 525.6524170853638
# connections number 2
# flights ['LAS', ('CLT', datetime.datetime(2015, 1, 3, 14, 15), datetime.datetime(2015, 1, 3, 21, 22)), ('JAX', datetime.datetime(2015, 1, 4, 7, 0), datetime.datetime(2015, 1, 4, 8, 27))]
#
#
# travel cost 349.09708939214397
# connections number 3
# flights ['LAS', ('FNT', datetime.datetime(2015, 1, 3, 10, 20), datetime.datetime(2015, 1, 3, 17, 5)), ('BWI', datetime.datetime(2015, 1, 3, 20, 20), datetime.datetime(2015, 1, 3, 22, 0)), ('JAX', datetime.datetime(2015, 1, 4, 7, 25), datetime.datetime(2015, 1, 4, 9, 25))]
#
#
# travel cost 533.6172811481947
# connections number 3
# flights ['LAS', ('DSM', datetime.datetime(2015, 1, 3, 12, 50), datetime.datetime(2015, 1, 3, 17, 40)), ('DFW', datetime.datetime(2015, 1, 3, 20, 45), datetime.datetime(2015, 1, 3, 22, 30)), ('JAX', datetime.datetime(2015, 1, 4, 6, 35), datetime.datetime(2015, 1, 4, 8, 25))]
# travel cost 446.00851502737396
# connections number 2
# flights ['LAS', ('IAH', datetime.datetime(2015, 1, 4, 7, 0), datetime.datetime(2015, 1, 4, 8, 20)), ('JAX', datetime.datetime(2015, 1, 4, 10, 16), datetime.datetime(2015, 1, 4, 13, 19))]
#
#
# travel cost 432.4499462606908
# connections number 2
# flights ['LAS', ('IAD', datetime.datetime(2015, 1, 4, 8, 5), datetime.datetime(2015, 1, 4, 10, 25)), ('JAX', datetime.datetime(2015, 1, 4, 12, 35), datetime.datetime(2015, 1, 4, 14, 43))]
#
#
# travel cost 619.582614381854
# connections number 3
# flights ['LAS', ('CVG', datetime.datetime(2015, 1, 3, 20, 10), datetime.datetime(2015, 1, 3, 21, 35)), ('MSP', datetime.datetime(2015, 1, 4, 7, 45), datetime.datetime(2015, 1, 4, 10, 53)), ('JAX', datetime.datetime(2015, 1, 4, 19, 40), datetime.datetime(2015, 1, 4, 23, 36))]
#
#
# travel cost 441.48346396707507
# connections number 3
# flights ['LAS', ('SAT', datetime.datetime(2015, 1, 4, 7, 0), datetime.datetime(2015, 1, 4, 8, 0)), ('ATL', datetime.datetime(2015, 1, 4, 10, 20), datetime.datetime(2015, 1, 4, 11, 40)), ('JAX', datetime.datetime(2015, 1, 4, 13, 53), datetime.datetime(2015, 1, 4, 14, 54))]
#
#
# travel cost 634.4661103658741
# connections number 3
# flights ['LAS', ('MKE', datetime.datetime(2015, 1, 4, 6, 5), datetime.datetime(2015, 1, 4, 8, 10)), ('EWR', datetime.datetime(2015, 1, 4, 10, 19), datetime.datetime(2015, 1, 4, 13, 28)), ('JAX', datetime.datetime(2015, 1, 4, 15, 37), datetime.datetime(2015, 1, 4, 18, 10))]
#
#
# travel cost 694.7837350696273
# connections number 2
# flights ['LAS', ('BWI', datetime.datetime(2015, 1, 4, 6, 0), datetime.datetime(2015, 1, 4, 13, 30)), ('JAX', datetime.datetime(2015, 1, 4, 16, 25), datetime.datetime(2015, 1, 4, 18, 30))]
#
#
# travel cost 680.7078572448427
# connections number 2
# flights ['LAS', ('ANC', datetime.datetime(2015, 1, 4, 23, 20), datetime.datetime(2015, 1, 4, 5, 30)), ('ADK', datetime.datetime(2015, 1, 4, 14, 0), datetime.datetime(2015, 1, 4, 16, 16))]
#
# ant dies :c None
#
# travel cost 535.2828154636713
# connections number 3
# flights ['LAS', ('AMA', datetime.datetime(2015, 1, 4, 9, 25), datetime.datetime(2015, 1, 4, 13, 20)), ('IAH', datetime.datetime(2015, 1, 4, 16, 43), datetime.datetime(2015, 1, 4, 18, 20)), ('JAX', datetime.datetime(2015, 1, 5, 6, 30), datetime.datetime(2015, 1, 5, 8, 5))]
#
#
# travel cost 558.6834242939208
# connections number 5
# flights ['LAS', ('ELP', datetime.datetime(2015, 1, 3, 17, 15), datetime.datetime(2015, 1, 3, 19, 50)), ('DAL', datetime.datetime(2015, 1, 4, 6, 0), datetime.datetime(2015, 1, 4, 8, 30)), ('LIT', datetime.datetime(2015, 1, 4, 15, 30), datetime.datetime(2015, 1, 4, 16, 40)), ('ORD', datetime.datetime(2015, 1, 4, 18, 25), datetime.datetime(2015, 1, 4, 20, 20)), ('JAX', datetime.datetime(2015, 1, 5, 7, 51), datetime.datetime(2015, 1, 5, 11, 14))]
#
#
# travel cost 516.359626689828
# connections number 2
# flights ['LAS', ('DEN', datetime.datetime(2015, 1, 4, 22, 6), datetime.datetime(2015, 1, 4, 23, 4)), ('JAX', datetime.datetime(2015, 1, 5, 9, 5), datetime.datetime(2015, 1, 5, 11, 5))]
#
#
# travel cost 458.940189762565
# connections number 2
# flights ['LAS', ('ORD', datetime.datetime(2015, 1, 4, 21, 35), datetime.datetime(2015, 1, 4, 23, 30)), ('JAX', datetime.datetime(2015, 1, 5, 7, 51), datetime.datetime(2015, 1, 5, 11, 14))]
#
#
# travel cost 341.5697628615076
# connections number 3
# flights ['LAS', ('ICT', datetime.datetime(2015, 1, 4, 10, 40), datetime.datetime(2015, 1, 4, 15, 5)), ('DFW', datetime.datetime(2015, 1, 4, 22, 30), datetime.datetime(2015, 1, 4, 23, 45)), ('JAX', datetime.datetime(2015, 1, 5, 6, 35), datetime.datetime(2015, 1, 5, 8, 25))]
#
#
# travel cost 479.4154697001327
# connections number 2
# flights ['LAS', ('MDW', datetime.datetime(2015, 1, 5, 6, 15), datetime.datetime(2015, 1, 5, 8, 15)), ('JAX', datetime.datetime(2015, 1, 5, 14, 0), datetime.datetime(2015, 1, 5, 17, 10))]
#
#
# travel cost 698.9720087440112
# connections number 2
# flights ['LAS', ('DCA', datetime.datetime(2015, 1, 5, 8, 25), datetime.datetime(2015, 1, 5, 10, 55)), ('JAX', datetime.datetime(2015, 1, 5, 13, 16), datetime.datetime(2015, 1, 5, 15, 0))]
#
#
# travel cost 602.519314365143
# connections number 4
# flights ['LAS', ('PHX', datetime.datetime(2015, 1, 4, 6, 35), datetime.datetime(2015, 1, 4, 8, 46)), ('SAN', datetime.datetime(2015, 1, 4, 10, 55), datetime.datetime(2015, 1, 4, 13, 5)), ('BNA', datetime.datetime(2015, 1, 5, 10, 35), datetime.datetime(2015, 1, 5, 13, 10)), ('JAX', datetime.datetime(2015, 1, 5, 16, 30), datetime.datetime(2015, 1, 5, 18, 55))]
#
#
# travel cost 447.4778748457396
# connections number 3
# flights ['LAS', ('LBB', datetime.datetime(2015, 1, 5, 11, 40), datetime.datetime(2015, 1, 5, 11, 55)), ('DEN', datetime.datetime(2015, 1, 5, 14, 1), datetime.datetime(2015, 1, 5, 14, 36)), ('JAX', datetime.datetime(2015, 1, 5, 17, 45), datetime.datetime(2015, 1, 5, 22, 50))]
#
#
# travel cost 339.19360708981924
# connections number 2
# flights ['LAS', ('ATL', datetime.datetime(2015, 1, 5, 15, 15), datetime.datetime(2015, 1, 5, 16, 55)), ('JAX', datetime.datetime(2015, 1, 5, 18, 35), datetime.datetime(2015, 1, 5, 20, 2))]
#
#
# travel cost 384.33004952969645
# connections number 2
# flights ['LAS', ('BNA', datetime.datetime(2015, 1, 5, 15, 25), datetime.datetime(2015, 1, 5, 17, 40)), ('JAX', datetime.datetime(2015, 1, 5, 19, 40), datetime.datetime(2015, 1, 5, 20, 15))]
#
#
# travel cost 665.035952848655
# connections number 4
# flights ['LAS', ('MIA', datetime.datetime(2015, 1, 4, 7, 0), datetime.datetime(2015, 1, 4, 9, 28)), ('CMH', datetime.datetime(2015, 1, 4, 17, 55), datetime.datetime(2015, 1, 4, 20, 38)), ('IAD', datetime.datetime(2015, 1, 5, 17, 8), datetime.datetime(2015, 1, 5, 18, 29)), ('JAX', datetime.datetime(2015, 1, 5, 21, 50), datetime.datetime(2015, 1, 5, 23, 51))]
#
#
# travel cost 206.61738097126053
# connections number 3
# flights ['LAS', ('ALB', datetime.datetime(2015, 1, 5, 13, 50), datetime.datetime(2015, 1, 5, 16, 30)), ('ATL', datetime.datetime(2015, 1, 5, 19, 22), datetime.datetime(2015, 1, 5, 21, 37)), ('JAX', datetime.datetime(2015, 1, 6, 5, 30), datetime.datetime(2015, 1, 6, 6, 40))]
#
#
# travel cost 817.8744059498481
# connections number 2
# flights ['LAS', ('FLL', datetime.datetime(2015, 1, 5, 15, 15), datetime.datetime(2015, 1, 5, 22, 45)), ('JAX', datetime.datetime(2015, 1, 6, 7, 0), datetime.datetime(2015, 1, 6, 8, 12))]
#
#
# travel cost 554.1133683259429
# connections number 3
# flights ['LAS', ('PIT', datetime.datetime(2015, 1, 5, 15, 15), datetime.datetime(2015, 1, 5, 17, 10)), ('BWI', datetime.datetime(2015, 1, 5, 22, 5), datetime.datetime(2015, 1, 5, 23, 5)), ('JAX', datetime.datetime(2015, 1, 6, 7, 40), datetime.datetime(2015, 1, 6, 9, 35))]
#
#
# travel cost 756.2262932796609
# connections number 2
# flights ['LAS', ('IAH', datetime.datetime(2015, 1, 6, 7, 20), datetime.datetime(2015, 1, 6, 8, 53)), ('JAX', datetime.datetime(2015, 1, 6, 13, 4), datetime.datetime(2015, 1, 6, 16, 9))]
#
#
# travel cost 487.5674037160348
# connections number 2
# flights ['LAS', ('BNA', datetime.datetime(2015, 1, 6, 7, 25), datetime.datetime(2015, 1, 6, 9, 45)), ('JAX', datetime.datetime(2015, 1, 6, 18, 0), datetime.datetime(2015, 1, 6, 20, 25))]
#
#
# travel cost 490.8253606899284
# connections number 2
# flights ['LAS', ('ORD', datetime.datetime(2015, 1, 6, 8, 14), datetime.datetime(2015, 1, 6, 10, 11)), ('JAX', datetime.datetime(2015, 1, 6, 12, 25), datetime.datetime(2015, 1, 6, 14, 14))]
#
#
# travel cost 490.8253606899284
# connections number 2
# flights ['LAS', ('ORD', datetime.datetime(2015, 1, 6, 8, 14), datetime.datetime(2015, 1, 6, 10, 11)), ('JAX', datetime.datetime(2015, 1, 6, 12, 25), datetime.datetime(2015, 1, 6, 14, 14))]
#
#
# travel cost 519.4295324281609
# connections number 2
# flights ['LAS', ('DEN', datetime.datetime(2015, 1, 6, 7, 30), datetime.datetime(2015, 1, 6, 10, 28)), ('JAX', datetime.datetime(2015, 1, 6, 13, 55), datetime.datetime(2015, 1, 6, 19, 0))]
#
#
# travel cost 296.86280369917085
# connections number 2
# flights ['LAS', ('HOU', datetime.datetime(2015, 1, 6, 9, 30), datetime.datetime(2015, 1, 6, 10, 55)), ('JAX', datetime.datetime(2015, 1, 6, 16, 50), datetime.datetime(2015, 1, 6, 18, 25))]
#
#
# travel cost 718.4815191287962
# connections number 2
# flights ['LAS', ('JFK', datetime.datetime(2015, 1, 6, 8, 0), datetime.datetime(2015, 1, 6, 11, 2)), ('JAX', datetime.datetime(2015, 1, 6, 14, 59), datetime.datetime(2015, 1, 6, 17, 47))]
#
#
# travel cost 465.8012363646284
# connections number 3
# flights ['LAS', ('ELP', datetime.datetime(2015, 1, 5, 17, 25), datetime.datetime(2015, 1, 5, 20, 0)), ('IAH', datetime.datetime(2015, 1, 6, 9, 12), datetime.datetime(2015, 1, 6, 12, 9)), ('JAX', datetime.datetime(2015, 1, 6, 18, 38), datetime.datetime(2015, 1, 6, 20, 19))]
#
#
# travel cost 388.4070065152133
# connections number 3
# flights ['LAS', ('CLE', datetime.datetime(2015, 1, 6, 7, 50), datetime.datetime(2015, 1, 6, 9, 38)), ('ATL', datetime.datetime(2015, 1, 6, 11, 11), datetime.datetime(2015, 1, 6, 13, 10)), ('JAX', datetime.datetime(2015, 1, 6, 14, 55), datetime.datetime(2015, 1, 6, 16, 3))]
#
#
# travel cost 569.0346564143371
# connections number 4
# flights ['LAS', ('LBB', datetime.datetime(2015, 1, 5, 17, 0), datetime.datetime(2015, 1, 5, 20, 55)), ('DAL', datetime.datetime(2015, 1, 6, 6, 25), datetime.datetime(2015, 1, 6, 7, 35)), ('BWI', datetime.datetime(2015, 1, 6, 10, 55), datetime.datetime(2015, 1, 6, 13, 30)), ('JAX', datetime.datetime(2015, 1, 6, 16, 10), datetime.datetime(2015, 1, 6, 18, 20))]
# travel cost 1310.077333602866
# connections number 7
# flights ['LAS', ('GEG', datetime.datetime(2015, 1, 5, 9, 20), datetime.datetime(2015, 1, 5, 11, 45)), ('PHX', datetime.datetime(2015, 1, 5, 13, 45), datetime.datetime(2015, 1, 5, 15, 30)), ('RNO', datetime.datetime(2015, 1, 5, 17, 50), datetime.datetime(2015, 1, 5, 18, 40)), ('SFO', datetime.datetime(2015, 1, 5, 20, 18), datetime.datetime(2015, 1, 5, 21, 28)), ('PHX', datetime.datetime(2015, 1, 6, 6, 0), datetime.datetime(2015, 1, 6, 8, 55)), ('IND', datetime.datetime(2015, 1, 6, 10, 50), datetime.datetime(2015, 1, 6, 13, 5)), ('SFO', datetime.datetime(2015, 1, 7, 7, 45), datetime.datetime(2015, 1, 7, 9, 57))]
#
# ant dies :c None
#
# travel cost 476.5410307308098
# connections number 3
# flights ['LAS', ('AMA', datetime.datetime(2015, 1, 6, 10, 55), datetime.datetime(2015, 1, 6, 14, 50)), ('IAH', datetime.datetime(2015, 1, 6, 16, 47), datetime.datetime(2015, 1, 6, 18, 26)), ('JAX', datetime.datetime(2015, 1, 7, 6, 30), datetime.datetime(2015, 1, 7, 8, 11))]
#
#
# travel cost 494.7660422717356
# connections number 3
# flights ['LAS', ('BOI', datetime.datetime(2015, 1, 6, 9, 25), datetime.datetime(2015, 1, 6, 12, 10)), ('IAH', datetime.datetime(2015, 1, 6, 17, 55), datetime.datetime(2015, 1, 6, 20, 48)), ('JAX', datetime.datetime(2015, 1, 7, 6, 30), datetime.datetime(2015, 1, 7, 8, 11))]
#
#
# travel cost 338.1798773918162
# connections number 2
# flights ['LAS', ('DFW', datetime.datetime(2015, 1, 7, 0, 58), datetime.datetime(2015, 1, 7, 5, 25)), ('JAX', datetime.datetime(2015, 1, 7, 7, 0), datetime.datetime(2015, 1, 7, 8, 55))]
#
#
# travel cost 595.686715581004
# connections number 3
# flights ['LAS', ('BUF', datetime.datetime(2015, 1, 6, 15, 0), datetime.datetime(2015, 1, 6, 22, 10)), ('ATL', datetime.datetime(2015, 1, 7, 6, 15), datetime.datetime(2015, 1, 7, 8, 51)), ('JAX', datetime.datetime(2015, 1, 7, 10, 50), datetime.datetime(2015, 1, 7, 12, 10))]
#
#
# travel cost 156.7434267845283
# connections number 2
# flights ['LAS', ('CLT', datetime.datetime(2015, 1, 7, 0, 59), datetime.datetime(2015, 1, 7, 8, 2)), ('JAX', datetime.datetime(2015, 1, 7, 10, 5), datetime.datetime(2015, 1, 7, 11, 34))]
#
#
# travel cost 118.49021670654474
# connections number 1
# flights ['LAS', ('BNA', datetime.datetime(2015, 1, 7, 7, 25), datetime.datetime(2015, 1, 7, 9, 45))]
#
# ant dies :c None
#
# travel cost 76.39191913332155
# connections number 1
# flights ['LAS', ('ABQ', datetime.datetime(2015, 1, 7, 7, 30), datetime.datetime(2015, 1, 7, 9, 55))]
#
# ant dies :c None
#
# travel cost 224.97285720991783
# connections number 2
# flights ['LAS', ('OKC', datetime.datetime(2015, 1, 7, 6, 0), datetime.datetime(2015, 1, 7, 7, 0)), ('DFW', datetime.datetime(2015, 1, 7, 9, 13), datetime.datetime(2015, 1, 7, 10, 10))]
#
# ant dies :c None
#
# travel cost 424.3193993754219
# connections number 1
# flights ['LAS', ('DCA', datetime.datetime(2015, 1, 7, 8, 25), datetime.datetime(2015, 1, 7, 10, 58))]
#
# ant dies :c None
#
# travel cost 1083.7434279413699
# connections number 4
# flights ['LAS', ('MIA', datetime.datetime(2015, 1, 6, 7, 55), datetime.datetime(2015, 1, 6, 15, 21)), ('LAS', datetime.datetime(2015, 1, 6, 20, 0), datetime.datetime(2015, 1, 6, 22, 39)), ('SAT', datetime.datetime(2015, 1, 7, 8, 0), datetime.datetime(2015, 1, 7, 9, 0)), ('DFW', datetime.datetime(2015, 1, 7, 10, 46), datetime.datetime(2015, 1, 7, 11, 55))]
#
# ant dies :c None
#
# travel cost 329.2015287755286
# connections number 2
# flights ['LAS', ('RNO', datetime.datetime(2015, 1, 7, 6, 5), datetime.datetime(2015, 1, 7, 7, 25)), ('DFW', datetime.datetime(2015, 1, 7, 10, 5), datetime.datetime(2015, 1, 7, 11, 43))]
#
# ant dies :c None
#
# travel cost 413.9460142612526
# connections number 2
# flights ['LAS', ('MDW', datetime.datetime(2015, 1, 7, 6, 10), datetime.datetime(2015, 1, 7, 8, 15)), ('BHM', datetime.datetime(2015, 1, 7, 10, 5), datetime.datetime(2015, 1, 7, 11, 55))]
#
# ant dies :c None
#
# travel cost 196.4982887981587
# connections number 1
# flights ['LAS', ('GEG', datetime.datetime(2015, 1, 7, 9, 35), datetime.datetime(2015, 1, 7, 12, 5))]
#
# ant dies :c None
#
# travel cost 106.52658049107043
# connections number 1
# flights ['LAS', ('BOI', datetime.datetime(2015, 1, 7, 9, 25), datetime.datetime(2015, 1, 7, 12, 10))]
#
# ant dies :c None
#
# travel cost 1128.3168219594304
# connections number 2
# flights ['LAS', ('HNL', datetime.datetime(2015, 1, 7, 1, 45), datetime.datetime(2015, 1, 7, 5, 55)), ('SJC', datetime.datetime(2015, 1, 7, 9, 10), datetime.datetime(2015, 1, 7, 12, 48))]
#
# ant dies :c None
#
# travel cost 231.02918448264396
# connections number 2
# flights ['LAS', ('ABQ', datetime.datetime(2015, 1, 5, 15, 20), datetime.datetime(2015, 1, 5, 15, 55)), ('ORD', datetime.datetime(2015, 1, 7, 10, 25), datetime.datetime(2015, 1, 7, 12, 33))]
#
# ant dies :c None
#
# travel cost 622.5751897388501
# connections number 2
# flights ['LAS', ('CMH', datetime.datetime(2015, 1, 7, 7, 25), datetime.datetime(2015, 1, 7, 9, 15)), ('TPA', datetime.datetime(2015, 1, 7, 10, 50), datetime.datetime(2015, 1, 7, 13, 5))]
#
# ant dies :c None
#
# travel cost 279.7413413861798
# connections number 1
# flights ['LAS', ('OMA', datetime.datetime(2015, 1, 7, 9, 0), datetime.datetime(2015, 1, 7, 13, 35))]
#
# ant dies :c None
#
# travel cost 455.137784176266
# connections number 2
# flights ['LAS', ('IND', datetime.datetime(2015, 1, 7, 8, 0), datetime.datetime(2015, 1, 7, 9, 25)), ('HOU', datetime.datetime(2015, 1, 7, 11, 5), datetime.datetime(2015, 1, 7, 14, 15))]
#
# ant dies :c None
#
# travel cost 478.9780607105313
# connections number 1
# flights ['LAS', ('PHL', datetime.datetime(2015, 1, 7, 6, 55), datetime.datetime(2015, 1, 7, 14, 26))]
#
# ant dies :c None
#
# travel cost 507.47073482700347
# connections number 1
# flights ['LAS', ('EWR', datetime.datetime(2015, 1, 7, 7, 15), datetime.datetime(2015, 1, 7, 15, 8))]
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 0
# connections number 0
# flights ['LAS']
#
# ant dies :c None
#
# travel cost 483.7268470274951
# connections number 1
# flights ['LAS', ('BHM', datetime.datetime(2015, 1, 7, 10, 45), datetime.datetime(2015, 1, 7, 16, 10))]
#
# ant dies :c None
#
# travel cost 464.94085235693416
# connections number 2
# flights ['LAS', ('SAN', datetime.datetime(2015, 1, 7, 6, 0), datetime.datetime(2015, 1, 7, 7, 10)), ('ATL', datetime.datetime(2015, 1, 7, 9, 15), datetime.datetime(2015, 1, 7, 16, 15))]
#
# ant dies :c None

# %%
print(datetime.datetime(2015, 1, 1, 8, 0) + datetime.timedelta(seconds=10))
