# %% [markdown]
# Rzeczy do (ewentualnego) poprawienia/obsłużenia:
# - zamiast zwykłego multigrafu, zrobić multigraf skierowany, bo traktujemy loty w jedną strone jako loty w obie naraz *//poniekąd obsłużone*
# - zawsze wyświetlana jest data wylotu. Oznacza to, że jeżeli przylot ma miejsce nastęonego dnia, ma on miejsce dzień później niż data w `arrival time` *//obsłużone*

# %%
import networkx as nx
import pandas as pd
import numpy as np
import queue
import datetime
import time
import random


def get_price(dist):
    return round(np.random.normal(0.20, 0.07) * dist, 2)

def parse_date(year, month, day, time):
    return datetime.datetime(year, month, day, int('{:04d}'.format(time)[:2]), int('{:04d}'.format(time)[2:]))

COLS = ['YEAR', 'MONTH', 'DAY', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT', 'SCHEDULED_DEPARTURE', 'DISTANCE', 'SCHEDULED_TIME', 'SCHEDULED_ARRIVAL']
N = 100000 #max = 5819079

flights = pd.read_csv("data/flights.csv")[COLS]
flights = flights.head(N)
flights = flights[flights['SCHEDULED_TIME'].notna()]
flights['PRICE'] = flights['DISTANCE'].apply(lambda x: get_price(x))
# print(flights.head(10))

MG = nx.MultiGraph()

for idx, row in flights.iterrows():
    departure_time = parse_date(row['YEAR'], row['MONTH'], row['DAY'], row['SCHEDULED_DEPARTURE'])
    arrival_time = parse_date(row['YEAR'], row['MONTH'], row['DAY'], row['SCHEDULED_ARRIVAL'])
    if arrival_time < departure_time:
        arrival_time += datetime.timedelta(days=1)

    MG.add_edge(row['ORIGIN_AIRPORT'], row['DESTINATION_AIRPORT'], origin=row['ORIGIN_AIRPORT'], destination=row['DESTINATION_AIRPORT'], departure_time=departure_time, arrival_time=arrival_time, flight_time=row['SCHEDULED_TIME'], price=row['PRICE'], pheromone_level=0, pheromone_update_time=0)
# Out:
# C:\Users\Robert\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
ANTS_NUMBER = 100
ANTS_SPAWN_ITERS = 10
SIMULATION_TIME_S = 20
SIMULATION_ITERS_NUM = 1000
CONNECTION_SAMPLES = 3
DIRECT_CONNECTION_IMPACT = 0.8
TIME_IMPACT = 0.4
COST_IMPACT = 0.2
PHEROMONE_IMPACT = 0.4
PHEROMONE_UPDATE = 0.5
PHEROMONE_UPDATING_TIME = 1000

# %%
class Ant:
    def __init__(self, curr_time, curr_airport):
        self.curr_time = curr_time
        self.curr_airport = curr_airport
        self.birth_time = curr_time
        
        self.curr_trav_cost = 0
        self.curr_conn_numb = 0
        self.mode = 'NORMAL'
        self.path = [curr_airport]
        
    def __lt__ (self, other):
        if self.mode != other.mode:
            return self.mode < other.mode
        return self.curr_time < other.curr_time
        
    def __gt__ (self, other):
        if self.mode != other.mode:
            return self.mode > other.mode
        return self.curr_time > other.curr_time

    def __eq__ (self, other):
        return self.mode == other.mode and self.curr_time == other.curr_time

    def __ne__ (self, other):
        return not self.__eq__(other)
    
    def print_ant(self):
        print(f'\ntravel cost: {self.curr_trav_cost}\nconnections number: {self.curr_conn_numb}\nflights:\n {self.path}\n')
        
    def update(self, next_flight):
        self.curr_time = next_flight[2]['arrival_time']
        self.curr_airport = next_flight[0]
        self.curr_trav_cost += next_flight[2]['price']
        self.curr_conn_numb += 1
        self.path.append((next_flight[0], next_flight[2]['departure_time'], next_flight[2]['arrival_time']))

# %%
#add max_conn_numb_handling
class AntColonyAlgorithm:
    def __init__(self, flights, origin, destination, min_time, max_time, min_conn_time, max_conn_numb, max_price):
        self.flights = flights
        self.origin = origin
        self.destination = destination
        self.min_time = min_time
        self.max_time = max_time
        self.min_conn_time = min_conn_time
        self.max_conn_numb = max_conn_numb
        self.max_price = max_price

        self.global_time = 0
        self.events = queue.PriorityQueue()

    def _init_ants(self):
        time_available_min = (self.max_time - self.min_time).total_seconds() // 60

        ants_spawn_gap = time_available_min // ANTS_SPAWN_ITERS
        for i in range(ANTS_SPAWN_ITERS):
            for j in range(ANTS_NUMBER // ANTS_SPAWN_ITERS):
                self.events.put((i * ants_spawn_gap, Ant(self.min_time + datetime.timedelta(minutes=i * ants_spawn_gap), self.origin)))
                
    def _run_next_event(self):
        self.global_time, curr_ant = self.events.get()
        available_flights = self._find_available_flights(curr_ant)
        self._update_pheromones(available_flights)
        next_flight = self._choose_flight(available_flights, curr_ant)
        self._make_next_flight(next_flight, curr_ant)

    ###
    def _find_available_flights(self, curr_ant):
        all_flights = self.flights[curr_ant.curr_airport]
        available_flights = []

        for airport in all_flights:
            flights_added = 0
            if curr_ant.mode == 'NORMAL':
                start, end, order = 0, len(self.flights.adj[curr_ant.curr_airport][airport]), 1
            else: # curr_ant.mode == 'RETURN'
                start, end, order = len(self.flights.adj[curr_ant.curr_airport][airport]) - 1, -1, -1

            for flight_idx in range(start, end, order):
                flight = self.flights.adj[curr_ant.curr_airport][airport][flight_idx]
                if self._is_accessible_flight(curr_ant, flight):
                    available_flights.append((airport, flight_idx, flight))
                    flights_added += 1
                    if flights_added == CONNECTION_SAMPLES:
                        break

        return available_flights

    def _is_accessible_flight(self, curr_ant, flight):
        if curr_ant.mode == 'NORMAL':
            good_airport = curr_ant.curr_airport == flight['origin']
            good_departure = curr_ant.curr_time + datetime.timedelta(minutes=self.min_conn_time) <= flight['departure_time']
            good_arrival = flight['arrival_time'] <= self.max_time
        else: # curr_ant.mode == 'RETURN'
            good_airport = curr_ant.curr_airport == flight['destination']
            good_arrival = curr_ant.curr_time - datetime.timedelta(minutes=self.min_conn_time) >= flight['arrival_time']
            good_departure = flight['departure_time'] >= self.min_time

        good_cost = curr_ant.curr_trav_cost + flight['price'] <= self.max_price
        # print(curr_ant.mode, good_airport, good_departure, good_arrival, good_cost)
        return good_airport and good_departure and good_arrival and good_cost

    ###
    def _update_pheromones(self, available_flights):
        for airport, index, flight in available_flights:
            time_gap = self.global_time - flight['pheromone_update_time']
            flight['pheromone_level'] = flight['pheromone_level'] * PHEROMONE_UPDATE ** (time_gap // PHEROMONE_UPDATING_TIME)
            flight['pheromone_update_time'] = self.global_time

    ###
    def _choose_flight(self, flights, curr_ant):
        if len(flights) == 0:
            return None

        for airport, index, flight in flights:
            if curr_ant.mode == 'NORMAL' and airport == self.destination or curr_ant.mode == 'RETURN' and airport == self.origin:
                if random.random() < DIRECT_CONNECTION_IMPACT:
                    flight['pheromone_level'] += 1
                    return airport, index, flight

        waiting_times, prices, pheromones = np.empty(len(flights)), np.empty(len(flights)), np.empty(len(flights))

        min_time = curr_ant.curr_time + datetime.timedelta(minutes=self.min_conn_time) if curr_ant.mode == 'NORMAL' else None
        max_time = curr_ant.curr_time - datetime.timedelta(minutes=self.min_conn_time) if curr_ant.mode == 'RETURN' else None

        for index, (airport, flight_index, flight) in enumerate(flights):
            if curr_ant.mode == 'NORMAL':
                waiting_times[index] = (flight['departure_time'] - min_time).total_seconds() // 60
            if curr_ant.mode == 'RETURN':
                waiting_times[index] = (max_time - flight['arrival_time']).total_seconds() // 60
            prices[index] = flight['price']
            pheromones[index] = flight['pheromone_level']

        time_coeffs = (1 - waiting_times / np.max(waiting_times)) ** 3
        prices_coeffs = (1 - prices / np.max(prices)) ** 3
        pheromones_coeffs = np.nan_to_num(pheromones / np.max(pheromones))
        combined_params = time_coeffs * TIME_IMPACT + prices_coeffs  * COST_IMPACT + pheromones_coeffs * PHEROMONE_IMPACT

        flight_pos = random.uniform(0, np.sum(combined_params))
        for flight, params in zip(flights, combined_params):
            if params >= flight_pos:
                flight[2]['pheromone_level'] += 1
                return flight
            flight_pos -= params

    ###
    def _kill_ant(self, curr_ant):
        print(f'ant died :c')
        curr_ant.print_ant()

    def _spawn_ant(self):
        time_available_min = (self.max_time - self.min_time).total_seconds() // 60
        ant_spawn_gap = random.randint(0, time_available_min)
        self.events.put((self.global_time + 1, Ant(self.min_time + datetime.timedelta(minutes=ant_spawn_gap), self.origin)))

    ###
    def _make_next_flight(self, next_flight, curr_ant):
        if next_flight is None:
            self._kill_ant(curr_ant)
            self._spawn_ant()

        else:
            if curr_ant.mode == 'NORMAL':
                time_diff = (next_flight[2]['arrival_time'] - curr_ant.curr_time).total_seconds() // 60
            else: #curr_ant.mode == 'RETURN'
                time_diff = (curr_ant.curr_time - next_flight[2]['departure_time']).total_seconds() // 60
            new_time = self.global_time + time_diff

            curr_ant.update(next_flight)
            if curr_ant.mode == 'NORMAL' and next_flight[0] == self.destination:
                print('ANT REACHED DESTINATION')
                curr_ant.print_ant()
                curr_ant.curr_trav_cost = 0
                curr_ant.mode = 'RETURN'
                self.events.put((new_time, curr_ant))
            elif curr_ant.mode == 'RETURN' and next_flight[0] == self.origin:
                print('ANT REACHED DESTINATION AND CAME BACK')
                curr_ant.print_ant()
                self._spawn_ant()
            else:
                self.events.put((new_time, curr_ant))

    ###
    def run(self, mode):
        self._init_ants()

        if mode == 'TIME':
            start_time = time.time()
            counter = 0
            while not self.events.empty() and (counter % 100 != 0 or time.time() - start_time < SIMULATION_TIME_S):
                self._run_next_event()
                counter += 1

        if mode == 'ITERS':
            counter = 0
            while not self.events.empty() and counter < SIMULATION_ITERS_NUM:
                self._run_next_event()
                counter += 1

# %%
simulation = AntColonyAlgorithm(MG, 'LAS', 'JAX', datetime.datetime(2015, 1, 1, 8, 0, 0), datetime.datetime(2015, 1, 8, 8, 0, 0), 90, 5, 5000)
simulation.run('ITERS')
print('DONE')
# Out:
# C:\Users\Robert\AppData\Local\Temp/ipykernel_7524/3836939644.py:100: RuntimeWarning: invalid value encountered in true_divide
#   pheromones_coeffs = np.nan_to_num(pheromones / np.max(pheromones))
# ANT REACHED DESTINATION
#
# travel cost: 454.74
# connections number: 2
# flights:
#  ['LAS', ('ORD', datetime.datetime(2015, 1, 1, 12, 15), datetime.datetime(2015, 1, 1, 18, 0)), ('JAX', datetime.datetime(2015, 1, 2, 7, 50), datetime.datetime(2015, 1, 2, 11, 13))]
#
# ANT REACHED DESTINATION
#
# travel cost: 460.67999999999995
# connections number: 2
# flights:
#  ['LAS', ('JFK', datetime.datetime(2015, 1, 1, 10, 15), datetime.datetime(2015, 1, 1, 18, 15)), ('JAX', datetime.datetime(2015, 1, 1, 20, 30), datetime.datetime(2015, 1, 1, 23, 10))]
#
# ANT REACHED DESTINATION
#
# travel cost: 642.88
# connections number: 2
# flights:
#  ['LAS', ('BWI', datetime.datetime(2015, 1, 1, 11, 5), datetime.datetime(2015, 1, 1, 18, 30)), ('JAX', datetime.datetime(2015, 1, 1, 20, 20), datetime.datetime(2015, 1, 1, 22, 25))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 526.74
# connections number: 4
# flights:
#  ['LAS', ('BWI', datetime.datetime(2015, 1, 1, 11, 5), datetime.datetime(2015, 1, 1, 18, 30)), ('JAX', datetime.datetime(2015, 1, 1, 20, 20), datetime.datetime(2015, 1, 1, 22, 25)), ('BNA', datetime.datetime(2015, 1, 1, 16, 30), datetime.datetime(2015, 1, 1, 18, 55)), ('LAS', datetime.datetime(2015, 1, 1, 9, 10), datetime.datetime(2015, 1, 1, 14, 35))]
#
# ANT REACHED DESTINATION
#
# travel cost: 474.15
# connections number: 4
# flights:
#  ['LAS', ('SAN', datetime.datetime(2015, 1, 1, 11, 15), datetime.datetime(2015, 1, 1, 12, 20)), ('LAX', datetime.datetime(2015, 1, 1, 15, 35), datetime.datetime(2015, 1, 1, 16, 20)), ('MSP', datetime.datetime(2015, 1, 2, 0, 33), datetime.datetime(2015, 1, 2, 6, 7)), ('JAX', datetime.datetime(2015, 1, 3, 19, 40), datetime.datetime(2015, 1, 3, 23, 35))]
#
# ANT REACHED DESTINATION
#
# travel cost: 507.28999999999996
# connections number: 2
# flights:
#  ['LAS', ('DEN', datetime.datetime(2015, 1, 2, 6, 45), datetime.datetime(2015, 1, 2, 9, 34)), ('JAX', datetime.datetime(2015, 1, 2, 17, 45), datetime.datetime(2015, 1, 2, 22, 50))]
#
# ANT REACHED DESTINATION
#
# travel cost: 421.8
# connections number: 3
# flights:
#  ['LAS', ('LIT', datetime.datetime(2015, 1, 1, 15, 30), datetime.datetime(2015, 1, 1, 20, 25)), ('LGA', datetime.datetime(2015, 1, 2, 6, 45), datetime.datetime(2015, 1, 2, 10, 10)), ('JAX', datetime.datetime(2015, 1, 3, 9, 40), datetime.datetime(2015, 1, 3, 12, 26))]
#
# ant died :c
#
# travel cost: 182.49
# connections number: 1
# flights:
#  ['LAS', ('PDX', datetime.datetime(2015, 1, 7, 10, 40), datetime.datetime(2015, 1, 7, 12, 53))]
#
# ant died :c
#
# travel cost: 110.42000000000002
# connections number: 4
# flights:
#  ['LAS', ('JFK', datetime.datetime(2015, 1, 1, 10, 15), datetime.datetime(2015, 1, 1, 18, 15)), ('JAX', datetime.datetime(2015, 1, 1, 20, 30), datetime.datetime(2015, 1, 1, 23, 10)), ('IAD', datetime.datetime(2015, 1, 1, 12, 35), datetime.datetime(2015, 1, 1, 14, 43)), ('RIC', datetime.datetime(2015, 1, 1, 10, 47), datetime.datetime(2015, 1, 1, 11, 40))]
#
# ANT REACHED DESTINATION
#
# travel cost: 632.01
# connections number: 3
# flights:
#  ['LAS', ('LAX', datetime.datetime(2015, 1, 2, 6, 0), datetime.datetime(2015, 1, 2, 7, 5)), ('MSP', datetime.datetime(2015, 1, 2, 9, 17), datetime.datetime(2015, 1, 2, 14, 54)), ('JAX', datetime.datetime(2015, 1, 2, 19, 40), datetime.datetime(2015, 1, 2, 23, 36))]
#
# ANT REACHED DESTINATION
#
# travel cost: 646.31
# connections number: 5
# flights:
#  ['LAS', ('RNO', datetime.datetime(2015, 1, 1, 11, 55), datetime.datetime(2015, 1, 1, 13, 15)), ('LAS', datetime.datetime(2015, 1, 1, 16, 0), datetime.datetime(2015, 1, 1, 17, 15)), ('MAF', datetime.datetime(2015, 1, 2, 10, 40), datetime.datetime(2015, 1, 2, 14, 40)), ('DFW', datetime.datetime(2015, 1, 2, 19, 55), datetime.datetime(2015, 1, 2, 21, 5)), ('JAX', datetime.datetime(2015, 1, 3, 8, 40), datetime.datetime(2015, 1, 3, 11, 55))]
#
# ANT REACHED DESTINATION
#
# travel cost: 376.24
# connections number: 2
# flights:
#  ['LAS', ('BNA', datetime.datetime(2015, 1, 1, 15, 15), datetime.datetime(2015, 1, 1, 20, 40)), ('JAX', datetime.datetime(2015, 1, 2, 8, 5), datetime.datetime(2015, 1, 2, 10, 30))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 657.2
# connections number: 5
# flights:
#  ['LAS', ('LAX', datetime.datetime(2015, 1, 2, 6, 0), datetime.datetime(2015, 1, 2, 7, 5)), ('MSP', datetime.datetime(2015, 1, 2, 9, 17), datetime.datetime(2015, 1, 2, 14, 54)), ('JAX', datetime.datetime(2015, 1, 2, 19, 40), datetime.datetime(2015, 1, 2, 23, 36)), ('PHL', datetime.datetime(2015, 1, 2, 18, 5), datetime.datetime(2015, 1, 2, 20, 32)), ('LAS', datetime.datetime(2015, 1, 2, 9, 0), datetime.datetime(2015, 1, 2, 16, 41))]
#
# ant died :c
#
# travel cost: 0
# connections number: 0
# flights:
#  ['LAS']
#
# ANT REACHED DESTINATION
#
# travel cost: 290.89
# connections number: 2
# flights:
#  ['LAS', ('MSP', datetime.datetime(2015, 1, 3, 0, 25), datetime.datetime(2015, 1, 3, 5, 26)), ('JAX', datetime.datetime(2015, 1, 3, 19, 40), datetime.datetime(2015, 1, 3, 23, 35))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 216.38
# connections number: 4
# flights:
#  ['LAS', ('DEN', datetime.datetime(2015, 1, 2, 6, 45), datetime.datetime(2015, 1, 2, 9, 34)), ('JAX', datetime.datetime(2015, 1, 2, 17, 45), datetime.datetime(2015, 1, 2, 22, 50)), ('EWR', datetime.datetime(2015, 1, 2, 10, 13), datetime.datetime(2015, 1, 2, 12, 46)), ('LAS', datetime.datetime(2015, 1, 1, 22, 13), datetime.datetime(2015, 1, 2, 6, 1))]
#
# ANT REACHED DESTINATION
#
# travel cost: 621.27
# connections number: 3
# flights:
#  ['LAS', ('OMA', datetime.datetime(2015, 1, 2, 19, 35), datetime.datetime(2015, 1, 3, 0, 10)), ('IAH', datetime.datetime(2015, 1, 3, 9, 46), datetime.datetime(2015, 1, 3, 12, 9)), ('JAX', datetime.datetime(2015, 1, 3, 13, 40), datetime.datetime(2015, 1, 3, 16, 43))]
#
# ant died :c
#
# travel cost: 184.68
# connections number: 4
# flights:
#  ['LAS', ('ORD', datetime.datetime(2015, 1, 1, 12, 15), datetime.datetime(2015, 1, 1, 18, 0)), ('JAX', datetime.datetime(2015, 1, 2, 7, 50), datetime.datetime(2015, 1, 2, 11, 13)), ('DCA', datetime.datetime(2015, 1, 1, 9, 35), datetime.datetime(2015, 1, 1, 11, 45)), ('MCO', datetime.datetime(2015, 1, 1, 8, 0), datetime.datetime(2015, 1, 1, 10, 5))]
#
# ant died :c
#
# travel cost: 0
# connections number: 0
# flights:
#  ['LAS']
#
# ANT REACHED DESTINATION
#
# travel cost: 444.65000000000003
# connections number: 2
# flights:
#  ['LAS', ('HOU', datetime.datetime(2015, 1, 3, 11, 45), datetime.datetime(2015, 1, 3, 16, 45)), ('JAX', datetime.datetime(2015, 1, 3, 20, 5), datetime.datetime(2015, 1, 3, 23, 0))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 467.68999999999994
# connections number: 4
# flights:
#  ['LAS', ('BNA', datetime.datetime(2015, 1, 1, 15, 15), datetime.datetime(2015, 1, 1, 20, 40)), ('JAX', datetime.datetime(2015, 1, 2, 8, 5), datetime.datetime(2015, 1, 2, 10, 30)), ('FLL', datetime.datetime(2015, 1, 2, 7, 5), datetime.datetime(2015, 1, 2, 8, 23)), ('LAS', datetime.datetime(2015, 1, 1, 21, 40), datetime.datetime(2015, 1, 2, 5, 4))]
#
# ANT REACHED DESTINATION
#
# travel cost: 776.49
# connections number: 3
# flights:
#  ['LAS', ('PIT', datetime.datetime(2015, 1, 2, 9, 45), datetime.datetime(2015, 1, 2, 16, 50)), ('MSP', datetime.datetime(2015, 1, 3, 17, 15), datetime.datetime(2015, 1, 3, 18, 34)), ('JAX', datetime.datetime(2015, 1, 4, 19, 40), datetime.datetime(2015, 1, 4, 23, 36))]
#
# ANT REACHED DESTINATION
#
# travel cost: 675.33
# connections number: 4
# flights:
#  ['LAS', ('MIA', datetime.datetime(2015, 1, 3, 0, 35), datetime.datetime(2015, 1, 3, 8, 3)), ('CVG', datetime.datetime(2015, 1, 3, 9, 34), datetime.datetime(2015, 1, 3, 12, 17)), ('ORD', datetime.datetime(2015, 1, 3, 19, 5), datetime.datetime(2015, 1, 3, 19, 22)), ('JAX', datetime.datetime(2015, 1, 4, 7, 51), datetime.datetime(2015, 1, 4, 11, 14))]
#
# ANT REACHED DESTINATION
#
# travel cost: 330.34
# connections number: 2
# flights:
#  ['LAS', ('BNA', datetime.datetime(2015, 1, 3, 15, 10), datetime.datetime(2015, 1, 3, 20, 35)), ('JAX', datetime.datetime(2015, 1, 4, 8, 5), datetime.datetime(2015, 1, 4, 10, 30))]
#
# ant died :c
#
# travel cost: 101.29
# connections number: 2
# flights:
#  ['LAS', ('SAN', datetime.datetime(2015, 1, 6, 20, 40), datetime.datetime(2015, 1, 6, 21, 45)), ('LAS', datetime.datetime(2015, 1, 7, 9, 28), datetime.datetime(2015, 1, 7, 10, 40))]
#
# ANT REACHED DESTINATION
#
# travel cost: 437.99
# connections number: 2
# flights:
#  ['LAS', ('CLT', datetime.datetime(2015, 1, 3, 14, 15), datetime.datetime(2015, 1, 3, 21, 22)), ('JAX', datetime.datetime(2015, 1, 4, 10, 5), datetime.datetime(2015, 1, 4, 11, 33))]
#
# ANT REACHED DESTINATION
#
# travel cost: 530.86
# connections number: 2
# flights:
#  ['LAS', ('IAD', datetime.datetime(2015, 1, 3, 16, 25), datetime.datetime(2015, 1, 3, 23, 50)), ('JAX', datetime.datetime(2015, 1, 4, 8, 24), datetime.datetime(2015, 1, 4, 10, 32))]
#
# ANT REACHED DESTINATION
#
# travel cost: 244.41000000000003
# connections number: 2
# flights:
#  ['LAS', ('DTW', datetime.datetime(2015, 1, 2, 8, 10), datetime.datetime(2015, 1, 2, 15, 2)), ('JAX', datetime.datetime(2015, 1, 3, 13, 55), datetime.datetime(2015, 1, 3, 16, 19))]
#
# ANT REACHED DESTINATION
#
# travel cost: 1092.13
# connections number: 4
# flights:
#  ['LAS', ('SAT', datetime.datetime(2015, 1, 2, 12, 10), datetime.datetime(2015, 1, 2, 16, 40)), ('SLC', datetime.datetime(2015, 1, 3, 14, 10), datetime.datetime(2015, 1, 3, 16, 11)), ('JFK', datetime.datetime(2015, 1, 3, 23, 59), datetime.datetime(2015, 1, 4, 6, 23)), ('JAX', datetime.datetime(2015, 1, 4, 14, 59), datetime.datetime(2015, 1, 4, 17, 47))]
#
# ANT REACHED DESTINATION
#
# travel cost: 407.01
# connections number: 3
# flights:
#  ['LAS', ('CLE', datetime.datetime(2015, 1, 2, 11, 0), datetime.datetime(2015, 1, 2, 17, 57)), ('BNA', datetime.datetime(2015, 1, 4, 6, 30), datetime.datetime(2015, 1, 4, 7, 15)), ('JAX', datetime.datetime(2015, 1, 4, 16, 30), datetime.datetime(2015, 1, 4, 18, 55))]
#
# ANT REACHED DESTINATION
#
# travel cost: 416.26
# connections number: 3
# flights:
#  ['LAS', ('MKE', datetime.datetime(2015, 1, 3, 13, 45), datetime.datetime(2015, 1, 3, 19, 10)), ('ORD', datetime.datetime(2015, 1, 4, 6, 33), datetime.datetime(2015, 1, 4, 7, 27)), ('JAX', datetime.datetime(2015, 1, 5, 7, 51), datetime.datetime(2015, 1, 5, 11, 14))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 767.7900000000001
# connections number: 7
# flights:
#  ['LAS', ('RNO', datetime.datetime(2015, 1, 1, 11, 55), datetime.datetime(2015, 1, 1, 13, 15)), ('LAS', datetime.datetime(2015, 1, 1, 16, 0), datetime.datetime(2015, 1, 1, 17, 15)), ('MAF', datetime.datetime(2015, 1, 2, 10, 40), datetime.datetime(2015, 1, 2, 14, 40)), ('DFW', datetime.datetime(2015, 1, 2, 19, 55), datetime.datetime(2015, 1, 2, 21, 5)), ('JAX', datetime.datetime(2015, 1, 3, 8, 40), datetime.datetime(2015, 1, 3, 11, 55)), ('EWR', datetime.datetime(2015, 1, 2, 15, 29), datetime.datetime(2015, 1, 2, 18, 2)), ('LAS', datetime.datetime(2015, 1, 2, 6, 40), datetime.datetime(2015, 1, 2, 14, 29))]
#
# ant died :c
#
# travel cost: 0
# connections number: 0
# flights:
#  ['LAS']
#
# ANT REACHED DESTINATION
#
# travel cost: 809.77
# connections number: 6
# flights:
#  ['LAS', ('SJC', datetime.datetime(2015, 1, 2, 15, 55), datetime.datetime(2015, 1, 2, 17, 20)), ('PHX', datetime.datetime(2015, 1, 2, 20, 40), datetime.datetime(2015, 1, 2, 23, 20)), ('MCO', datetime.datetime(2015, 1, 3, 9, 55), datetime.datetime(2015, 1, 3, 16, 4)), ('ISP', datetime.datetime(2015, 1, 3, 18, 55), datetime.datetime(2015, 1, 3, 21, 20)), ('BWI', datetime.datetime(2015, 1, 4, 7, 55), datetime.datetime(2015, 1, 4, 9, 15)), ('JAX', datetime.datetime(2015, 1, 4, 16, 25), datetime.datetime(2015, 1, 4, 18, 30))]
#
# ANT REACHED DESTINATION
#
# travel cost: 253.35
# connections number: 3
# flights:
#  ['LAS', ('SAN', datetime.datetime(2015, 1, 5, 8, 10), datetime.datetime(2015, 1, 5, 9, 15)), ('HOU', datetime.datetime(2015, 1, 5, 14, 25), datetime.datetime(2015, 1, 5, 19, 25)), ('JAX', datetime.datetime(2015, 1, 6, 10, 40), datetime.datetime(2015, 1, 6, 13, 35))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 631.59
# connections number: 4
# flights:
#  ['LAS', ('MSP', datetime.datetime(2015, 1, 3, 0, 25), datetime.datetime(2015, 1, 3, 5, 26)), ('JAX', datetime.datetime(2015, 1, 3, 19, 40), datetime.datetime(2015, 1, 3, 23, 35)), ('IAD', datetime.datetime(2015, 1, 3, 12, 35), datetime.datetime(2015, 1, 3, 14, 43)), ('LAS', datetime.datetime(2015, 1, 2, 22, 55), datetime.datetime(2015, 1, 3, 6, 15))]
#
# ANT REACHED DESTINATION
#
# travel cost: 516.79
# connections number: 3
# flights:
#  ['LAS', ('SAT', datetime.datetime(2015, 1, 3, 12, 10), datetime.datetime(2015, 1, 3, 16, 40)), ('BNA', datetime.datetime(2015, 1, 4, 9, 15), datetime.datetime(2015, 1, 4, 11, 15)), ('JAX', datetime.datetime(2015, 1, 4, 16, 30), datetime.datetime(2015, 1, 4, 18, 55))]
#
# ANT REACHED DESTINATION
#
# travel cost: 597.5799999999999
# connections number: 3
# flights:
#  ['LAS', ('ONT', datetime.datetime(2015, 1, 3, 13, 10), datetime.datetime(2015, 1, 3, 14, 5)), ('MDW', datetime.datetime(2015, 1, 4, 6, 20), datetime.datetime(2015, 1, 4, 12, 10)), ('JAX', datetime.datetime(2015, 1, 4, 14, 0), datetime.datetime(2015, 1, 4, 17, 10))]
#
# ANT REACHED DESTINATION
#
# travel cost: 712.9300000000001
# connections number: 3
# flights:
#  ['LAS', ('SEA', datetime.datetime(2015, 1, 3, 13, 0), datetime.datetime(2015, 1, 3, 15, 35)), ('DTW', datetime.datetime(2015, 1, 4, 6, 0), datetime.datetime(2015, 1, 4, 13, 12)), ('JAX', datetime.datetime(2015, 1, 6, 15, 46), datetime.datetime(2015, 1, 6, 18, 11))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 436.10999999999996
# connections number: 5
# flights:
#  ['LAS', ('OMA', datetime.datetime(2015, 1, 2, 19, 35), datetime.datetime(2015, 1, 3, 0, 10)), ('IAH', datetime.datetime(2015, 1, 3, 9, 46), datetime.datetime(2015, 1, 3, 12, 9)), ('JAX', datetime.datetime(2015, 1, 3, 13, 40), datetime.datetime(2015, 1, 3, 16, 43)), ('FLL', datetime.datetime(2015, 1, 2, 19, 45), datetime.datetime(2015, 1, 2, 21, 3)), ('LAS', datetime.datetime(2015, 1, 1, 22, 49), datetime.datetime(2015, 1, 2, 6, 6))]
#
# ANT REACHED DESTINATION
#
# travel cost: 1014.46
# connections number: 4
# flights:
#  ['LAS', ('GEG', datetime.datetime(2015, 1, 3, 9, 20), datetime.datetime(2015, 1, 3, 11, 45)), ('SEA', datetime.datetime(2015, 1, 3, 14, 5), datetime.datetime(2015, 1, 3, 15, 3)), ('EWR', datetime.datetime(2015, 1, 4, 5, 59), datetime.datetime(2015, 1, 4, 14, 10)), ('JAX', datetime.datetime(2015, 1, 4, 21, 0), datetime.datetime(2015, 1, 4, 23, 37))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 439.9
# connections number: 4
# flights:
#  ['LAS', ('CLT', datetime.datetime(2015, 1, 3, 14, 15), datetime.datetime(2015, 1, 3, 21, 22)), ('JAX', datetime.datetime(2015, 1, 4, 10, 5), datetime.datetime(2015, 1, 4, 11, 33)), ('ATL', datetime.datetime(2015, 1, 4, 8, 45), datetime.datetime(2015, 1, 4, 10, 0)), ('LAS', datetime.datetime(2015, 1, 4, 0, 30), datetime.datetime(2015, 1, 4, 7, 11))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 554.0
# connections number: 6
# flights:
#  ['LAS', ('SAN', datetime.datetime(2015, 1, 1, 11, 15), datetime.datetime(2015, 1, 1, 12, 20)), ('LAX', datetime.datetime(2015, 1, 1, 15, 35), datetime.datetime(2015, 1, 1, 16, 20)), ('MSP', datetime.datetime(2015, 1, 2, 0, 33), datetime.datetime(2015, 1, 2, 6, 7)), ('JAX', datetime.datetime(2015, 1, 3, 19, 40), datetime.datetime(2015, 1, 3, 23, 35)), ('JFK', datetime.datetime(2015, 1, 3, 8, 0), datetime.datetime(2015, 1, 3, 10, 38)), ('LAS', datetime.datetime(2015, 1, 2, 23, 19), datetime.datetime(2015, 1, 3, 7, 0))]
#
# ANT REACHED DESTINATION
#
# travel cost: 591.13
# connections number: 2
# flights:
#  ['LAS', ('IAH', datetime.datetime(2015, 1, 4, 11, 13), datetime.datetime(2015, 1, 4, 16, 13)), ('JAX', datetime.datetime(2015, 1, 4, 19, 0), datetime.datetime(2015, 1, 4, 22, 1))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 645.23
# connections number: 5
# flights:
#  ['LAS', ('LIT', datetime.datetime(2015, 1, 1, 15, 30), datetime.datetime(2015, 1, 1, 20, 25)), ('LGA', datetime.datetime(2015, 1, 2, 6, 45), datetime.datetime(2015, 1, 2, 10, 10)), ('JAX', datetime.datetime(2015, 1, 3, 9, 40), datetime.datetime(2015, 1, 3, 12, 26)), ('IAD', datetime.datetime(2015, 1, 2, 8, 24), datetime.datetime(2015, 1, 2, 10, 32)), ('LAS', datetime.datetime(2015, 1, 1, 22, 55), datetime.datetime(2015, 1, 2, 6, 15))]
#
# ANT REACHED DESTINATION
#
# travel cost: 944.23
# connections number: 3
# flights:
#  ['LAS', ('BHM', datetime.datetime(2015, 1, 3, 13, 0), datetime.datetime(2015, 1, 3, 18, 25)), ('DEN', datetime.datetime(2015, 1, 4, 15, 29), datetime.datetime(2015, 1, 4, 17, 44)), ('JAX', datetime.datetime(2015, 1, 6, 13, 55), datetime.datetime(2015, 1, 6, 19, 0))]
#
# ANT REACHED DESTINATION
#
# travel cost: 538.72
# connections number: 3
# flights:
#  ['LAS', ('STL', datetime.datetime(2015, 1, 3, 8, 40), datetime.datetime(2015, 1, 3, 13, 40)), ('DCA', datetime.datetime(2015, 1, 4, 15, 15), datetime.datetime(2015, 1, 4, 18, 5)), ('JAX', datetime.datetime(2015, 1, 5, 10, 20), datetime.datetime(2015, 1, 5, 12, 30))]
#
# ANT REACHED DESTINATION
#
# travel cost: 598.49
# connections number: 2
# flights:
#  ['LAS', ('DEN', datetime.datetime(2015, 1, 3, 6, 15), datetime.datetime(2015, 1, 3, 9, 12)), ('JAX', datetime.datetime(2015, 1, 3, 17, 45), datetime.datetime(2015, 1, 3, 22, 50))]
#
# ANT REACHED DESTINATION
#
# travel cost: 1172.27
# connections number: 7
# flights:
#  ['LAS', ('ELP', datetime.datetime(2015, 1, 1, 9, 50), datetime.datetime(2015, 1, 1, 12, 25)), ('SAT', datetime.datetime(2015, 1, 2, 7, 5), datetime.datetime(2015, 1, 2, 9, 25)), ('SFO', datetime.datetime(2015, 1, 2, 20, 6), datetime.datetime(2015, 1, 2, 22, 7)), ('SLC', datetime.datetime(2015, 1, 3, 11, 55), datetime.datetime(2015, 1, 3, 14, 47)), ('PSC', datetime.datetime(2015, 1, 4, 11, 22), datetime.datetime(2015, 1, 4, 12, 17)), ('DEN', datetime.datetime(2015, 1, 4, 18, 4), datetime.datetime(2015, 1, 4, 21, 14)), ('JAX', datetime.datetime(2015, 1, 5, 17, 45), datetime.datetime(2015, 1, 5, 22, 50))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 420.85
# connections number: 5
# flights:
#  ['LAS', ('ONT', datetime.datetime(2015, 1, 3, 13, 10), datetime.datetime(2015, 1, 3, 14, 5)), ('MDW', datetime.datetime(2015, 1, 4, 6, 20), datetime.datetime(2015, 1, 4, 12, 10)), ('JAX', datetime.datetime(2015, 1, 4, 14, 0), datetime.datetime(2015, 1, 4, 17, 10)), ('ATL', datetime.datetime(2015, 1, 4, 12, 15), datetime.datetime(2015, 1, 4, 13, 24)), ('LAS', datetime.datetime(2015, 1, 4, 0, 30), datetime.datetime(2015, 1, 4, 7, 11))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 357.43
# connections number: 5
# flights:
#  ['LAS', ('CLE', datetime.datetime(2015, 1, 2, 11, 0), datetime.datetime(2015, 1, 2, 17, 57)), ('BNA', datetime.datetime(2015, 1, 4, 6, 30), datetime.datetime(2015, 1, 4, 7, 15)), ('JAX', datetime.datetime(2015, 1, 4, 16, 30), datetime.datetime(2015, 1, 4, 18, 55)), ('ATL', datetime.datetime(2015, 1, 4, 15, 12), datetime.datetime(2015, 1, 4, 16, 19)), ('LAS', datetime.datetime(2015, 1, 4, 7, 15), datetime.datetime(2015, 1, 4, 13, 59))]
#
# ANT REACHED DESTINATION
#
# travel cost: 298.23
# connections number: 2
# flights:
#  ['LAS', ('FLL', datetime.datetime(2015, 1, 4, 15, 20), datetime.datetime(2015, 1, 4, 22, 50)), ('JAX', datetime.datetime(2015, 1, 5, 19, 45), datetime.datetime(2015, 1, 5, 21, 3))]
#
# ANT REACHED DESTINATION
#
# travel cost: 311.14
# connections number: 2
# flights:
#  ['LAS', ('DEN', datetime.datetime(2015, 1, 5, 6, 45), datetime.datetime(2015, 1, 5, 9, 34)), ('JAX', datetime.datetime(2015, 1, 5, 17, 45), datetime.datetime(2015, 1, 5, 22, 50))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 479.96
# connections number: 5
# flights:
#  ['LAS', ('PIT', datetime.datetime(2015, 1, 2, 9, 45), datetime.datetime(2015, 1, 2, 16, 50)), ('MSP', datetime.datetime(2015, 1, 3, 17, 15), datetime.datetime(2015, 1, 3, 18, 34)), ('JAX', datetime.datetime(2015, 1, 4, 19, 40), datetime.datetime(2015, 1, 4, 23, 36)), ('BNA', datetime.datetime(2015, 1, 4, 19, 15), datetime.datetime(2015, 1, 4, 21, 40)), ('LAS', datetime.datetime(2015, 1, 4, 9, 35), datetime.datetime(2015, 1, 4, 15, 0))]
#
# ANT REACHED DESTINATION
#
# travel cost: 621.1700000000001
# connections number: 2
# flights:
#  ['LAS', ('FLL', datetime.datetime(2015, 1, 4, 21, 40), datetime.datetime(2015, 1, 5, 5, 4)), ('JAX', datetime.datetime(2015, 1, 5, 19, 45), datetime.datetime(2015, 1, 5, 21, 3))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 385.46999999999997
# connections number: 8
# flights:
#  ['LAS', ('SJC', datetime.datetime(2015, 1, 2, 15, 55), datetime.datetime(2015, 1, 2, 17, 20)), ('PHX', datetime.datetime(2015, 1, 2, 20, 40), datetime.datetime(2015, 1, 2, 23, 20)), ('MCO', datetime.datetime(2015, 1, 3, 9, 55), datetime.datetime(2015, 1, 3, 16, 4)), ('ISP', datetime.datetime(2015, 1, 3, 18, 55), datetime.datetime(2015, 1, 3, 21, 20)), ('BWI', datetime.datetime(2015, 1, 4, 7, 55), datetime.datetime(2015, 1, 4, 9, 15)), ('JAX', datetime.datetime(2015, 1, 4, 16, 25), datetime.datetime(2015, 1, 4, 18, 30)), ('FLL', datetime.datetime(2015, 1, 4, 7, 5), datetime.datetime(2015, 1, 4, 8, 23)), ('LAS', datetime.datetime(2015, 1, 3, 22, 49), datetime.datetime(2015, 1, 4, 6, 6))]
#
# ANT REACHED DESTINATION
#
# travel cost: 520.46
# connections number: 4
# flights:
#  ['LAS', ('LGB', datetime.datetime(2015, 1, 4, 7, 5), datetime.datetime(2015, 1, 4, 8, 10)), ('SLC', datetime.datetime(2015, 1, 4, 13, 5), datetime.datetime(2015, 1, 4, 15, 54)), ('ATL', datetime.datetime(2015, 1, 4, 23, 55), datetime.datetime(2015, 1, 5, 5, 20)), ('JAX', datetime.datetime(2015, 1, 5, 8, 10), datetime.datetime(2015, 1, 5, 9, 16))]
#
# ANT REACHED DESTINATION
#
# travel cost: 458.31000000000006
# connections number: 3
# flights:
#  ['LAS', ('STL', datetime.datetime(2015, 1, 3, 8, 40), datetime.datetime(2015, 1, 3, 13, 40)), ('DTW', datetime.datetime(2015, 1, 3, 16, 32), datetime.datetime(2015, 1, 3, 19, 5)), ('JAX', datetime.datetime(2015, 1, 5, 15, 46), datetime.datetime(2015, 1, 5, 18, 11))]
#
# ANT REACHED DESTINATION
#
# travel cost: 654.49
# connections number: 4
# flights:
#  ['LAS', ('LGB', datetime.datetime(2015, 1, 4, 7, 5), datetime.datetime(2015, 1, 4, 8, 10)), ('SFO', datetime.datetime(2015, 1, 4, 20, 31), datetime.datetime(2015, 1, 4, 21, 56)), ('IAH', datetime.datetime(2015, 1, 5, 0, 45), datetime.datetime(2015, 1, 5, 6, 17)), ('JAX', datetime.datetime(2015, 1, 5, 10, 16), datetime.datetime(2015, 1, 5, 13, 19))]
#
# ANT REACHED DESTINATION
#
# travel cost: 1054.0700000000002
# connections number: 9
# flights:
#  ['LAS', ('TUS', datetime.datetime(2015, 1, 2, 8, 50), datetime.datetime(2015, 1, 2, 11, 0)), ('LAX', datetime.datetime(2015, 1, 2, 14, 35), datetime.datetime(2015, 1, 2, 15, 10)), ('OAK', datetime.datetime(2015, 1, 2, 19, 20), datetime.datetime(2015, 1, 2, 20, 35)), ('SLC', datetime.datetime(2015, 1, 3, 8, 55), datetime.datetime(2015, 1, 3, 11, 35)), ('LWS', datetime.datetime(2015, 1, 3, 21, 57), datetime.datetime(2015, 1, 3, 22, 44)), ('SLC', datetime.datetime(2015, 1, 4, 12, 10), datetime.datetime(2015, 1, 4, 14, 38)), ('PHX', datetime.datetime(2015, 1, 4, 17, 35), datetime.datetime(2015, 1, 4, 19, 10)), ('DTW', datetime.datetime(2015, 1, 5, 0, 40), datetime.datetime(2015, 1, 5, 6, 20)), ('JAX', datetime.datetime(2015, 1, 5, 15, 46), datetime.datetime(2015, 1, 5, 18, 11))]
#
# ANT REACHED DESTINATION
#
# travel cost: 852.63
# connections number: 5
# flights:
#  ['LAS', ('SMF', datetime.datetime(2015, 1, 4, 7, 30), datetime.datetime(2015, 1, 4, 8, 55)), ('PDX', datetime.datetime(2015, 1, 4, 10, 45), datetime.datetime(2015, 1, 4, 12, 15)), ('SFO', datetime.datetime(2015, 1, 4, 18, 55), datetime.datetime(2015, 1, 4, 20, 51)), ('DTW', datetime.datetime(2015, 1, 4, 22, 55), datetime.datetime(2015, 1, 5, 6, 27)), ('JAX', datetime.datetime(2015, 1, 5, 15, 46), datetime.datetime(2015, 1, 5, 18, 11))]
#
# ANT REACHED DESTINATION
#
# travel cost: 277.26
# connections number: 2
# flights:
#  ['LAS', ('ORD', datetime.datetime(2015, 1, 5, 1, 10), datetime.datetime(2015, 1, 5, 6, 45)), ('JAX', datetime.datetime(2015, 1, 7, 8, 30), datetime.datetime(2015, 1, 7, 11, 49))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 341.21000000000004
# connections number: 4
# flights:
#  ['LAS', ('HOU', datetime.datetime(2015, 1, 3, 11, 45), datetime.datetime(2015, 1, 3, 16, 45)), ('JAX', datetime.datetime(2015, 1, 3, 20, 5), datetime.datetime(2015, 1, 3, 23, 0)), ('MDW', datetime.datetime(2015, 1, 2, 14, 0), datetime.datetime(2015, 1, 2, 17, 10)), ('LAS', datetime.datetime(2015, 1, 2, 9, 50), datetime.datetime(2015, 1, 2, 15, 15))]
#
# ANT REACHED DESTINATION
#
# travel cost: 573.25
# connections number: 4
# flights:
#  ['LAS', ('SFO', datetime.datetime(2015, 1, 3, 13, 20), datetime.datetime(2015, 1, 3, 14, 50)), ('OKC', datetime.datetime(2015, 1, 4, 10, 45), datetime.datetime(2015, 1, 4, 16, 0)), ('DFW', datetime.datetime(2015, 1, 5, 7, 5), datetime.datetime(2015, 1, 5, 8, 10)), ('JAX', datetime.datetime(2015, 1, 5, 11, 15), datetime.datetime(2015, 1, 5, 14, 25))]
#
# ant died :c
#
# travel cost: 240.14000000000001
# connections number: 4
# flights:
#  ['LAS', ('ELP', datetime.datetime(2015, 1, 6, 9, 50), datetime.datetime(2015, 1, 6, 12, 25)), ('DAL', datetime.datetime(2015, 1, 6, 17, 25), datetime.datetime(2015, 1, 6, 20, 0)), ('OKC', datetime.datetime(2015, 1, 7, 8, 20), datetime.datetime(2015, 1, 7, 9, 10)), ('IAH', datetime.datetime(2015, 1, 7, 10, 42), datetime.datetime(2015, 1, 7, 12, 10))]
#
# ANT REACHED DESTINATION
#
# travel cost: 323.59000000000003
# connections number: 2
# flights:
#  ['LAS', ('DEN', datetime.datetime(2015, 1, 5, 5, 50), datetime.datetime(2015, 1, 5, 8, 45)), ('JAX', datetime.datetime(2015, 1, 5, 17, 45), datetime.datetime(2015, 1, 5, 22, 50))]
#
# ANT REACHED DESTINATION
#
# travel cost: 1249.6799999999998
# connections number: 6
# flights:
#  ['LAS', ('GEG', datetime.datetime(2015, 1, 3, 9, 20), datetime.datetime(2015, 1, 3, 11, 45)), ('MSP', datetime.datetime(2015, 1, 3, 13, 35), datetime.datetime(2015, 1, 3, 18, 27)), ('SEA', datetime.datetime(2015, 1, 4, 7, 0), datetime.datetime(2015, 1, 4, 8, 53)), ('FAT', datetime.datetime(2015, 1, 4, 18, 55), datetime.datetime(2015, 1, 4, 20, 52)), ('DEN', datetime.datetime(2015, 1, 5, 6, 0), datetime.datetime(2015, 1, 5, 9, 25)), ('JAX', datetime.datetime(2015, 1, 5, 17, 45), datetime.datetime(2015, 1, 5, 22, 50))]
#
# ant died :c
#
# travel cost: 258.73
# connections number: 1
# flights:
#  ['LAS', ('PDX', datetime.datetime(2015, 1, 7, 10, 15), datetime.datetime(2015, 1, 7, 12, 35))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 823.72
# connections number: 4
# flights:
#  ['LAS', ('IAH', datetime.datetime(2015, 1, 4, 11, 13), datetime.datetime(2015, 1, 4, 16, 13)), ('JAX', datetime.datetime(2015, 1, 4, 19, 0), datetime.datetime(2015, 1, 4, 22, 1)), ('BWI', datetime.datetime(2015, 1, 4, 8, 35), datetime.datetime(2015, 1, 4, 10, 45)), ('LAS', datetime.datetime(2015, 1, 3, 23, 50), datetime.datetime(2015, 1, 4, 7, 10))]
#
# ANT REACHED DESTINATION
#
# travel cost: 1276.2599999999998
# connections number: 6
# flights:
#  ['LAS', ('BLI', datetime.datetime(2015, 1, 1, 13, 15), datetime.datetime(2015, 1, 1, 16, 0)), ('HNL', datetime.datetime(2015, 1, 3, 17, 40), datetime.datetime(2015, 1, 3, 22, 12)), ('PHX', datetime.datetime(2015, 1, 3, 23, 50), datetime.datetime(2015, 1, 4, 8, 40)), ('ABQ', datetime.datetime(2015, 1, 4, 10, 35), datetime.datetime(2015, 1, 4, 11, 40)), ('DFW', datetime.datetime(2015, 1, 5, 9, 0), datetime.datetime(2015, 1, 5, 11, 45)), ('JAX', datetime.datetime(2015, 1, 5, 14, 30), datetime.datetime(2015, 1, 5, 17, 45))]
#
# ANT REACHED DESTINATION
#
# travel cost: 1676.9800000000002
# connections number: 6
# flights:
#  ['LAS', ('SJC', datetime.datetime(2015, 1, 2, 8, 40), datetime.datetime(2015, 1, 2, 10, 5)), ('LAS', datetime.datetime(2015, 1, 2, 14, 0), datetime.datetime(2015, 1, 2, 15, 20)), ('OAK', datetime.datetime(2015, 1, 2, 21, 40), datetime.datetime(2015, 1, 2, 23, 10)), ('HNL', datetime.datetime(2015, 1, 4, 9, 35), datetime.datetime(2015, 1, 4, 13, 10)), ('EWR', datetime.datetime(2015, 1, 4, 21, 25), datetime.datetime(2015, 1, 5, 12, 1)), ('JAX', datetime.datetime(2015, 1, 5, 15, 29), datetime.datetime(2015, 1, 5, 18, 2))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 613.63
# connections number: 4
# flights:
#  ['LAS', ('DTW', datetime.datetime(2015, 1, 2, 8, 10), datetime.datetime(2015, 1, 2, 15, 2)), ('JAX', datetime.datetime(2015, 1, 3, 13, 55), datetime.datetime(2015, 1, 3, 16, 19)), ('IAH', datetime.datetime(2015, 1, 3, 10, 16), datetime.datetime(2015, 1, 3, 13, 19)), ('LAS', datetime.datetime(2015, 1, 3, 0, 46), datetime.datetime(2015, 1, 3, 5, 40))]
#
# ANT REACHED DESTINATION
#
# travel cost: 513.2
# connections number: 3
# flights:
#  ['LAS', ('MIA', datetime.datetime(2015, 1, 4, 11, 0), datetime.datetime(2015, 1, 4, 18, 38)), ('BWI', datetime.datetime(2015, 1, 5, 9, 30), datetime.datetime(2015, 1, 5, 12, 8)), ('JAX', datetime.datetime(2015, 1, 5, 16, 30), datetime.datetime(2015, 1, 5, 18, 35))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 554.0
# connections number: 4
# flights:
#  ['LAS', ('IAD', datetime.datetime(2015, 1, 3, 16, 25), datetime.datetime(2015, 1, 3, 23, 50)), ('JAX', datetime.datetime(2015, 1, 4, 8, 24), datetime.datetime(2015, 1, 4, 10, 32)), ('JFK', datetime.datetime(2015, 1, 3, 8, 0), datetime.datetime(2015, 1, 3, 10, 38)), ('LAS', datetime.datetime(2015, 1, 2, 23, 19), datetime.datetime(2015, 1, 3, 7, 0))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 385.46999999999997
# connections number: 6
# flights:
#  ['LAS', ('GEG', datetime.datetime(2015, 1, 3, 9, 20), datetime.datetime(2015, 1, 3, 11, 45)), ('SEA', datetime.datetime(2015, 1, 3, 14, 5), datetime.datetime(2015, 1, 3, 15, 3)), ('EWR', datetime.datetime(2015, 1, 4, 5, 59), datetime.datetime(2015, 1, 4, 14, 10)), ('JAX', datetime.datetime(2015, 1, 4, 21, 0), datetime.datetime(2015, 1, 4, 23, 37)), ('FLL', datetime.datetime(2015, 1, 4, 7, 5), datetime.datetime(2015, 1, 4, 8, 23)), ('LAS', datetime.datetime(2015, 1, 3, 22, 49), datetime.datetime(2015, 1, 4, 6, 6))]
#
# ANT REACHED DESTINATION
#
# travel cost: 493.27
# connections number: 3
# flights:
#  ['LAS', ('STL', datetime.datetime(2015, 1, 6, 10, 10), datetime.datetime(2015, 1, 6, 15, 15)), ('EWR', datetime.datetime(2015, 1, 7, 5, 50), datetime.datetime(2015, 1, 7, 9, 7)), ('JAX', datetime.datetime(2015, 1, 7, 10, 59), datetime.datetime(2015, 1, 7, 13, 38))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 904.92
# connections number: 5
# flights:
#  ['LAS', ('STL', datetime.datetime(2015, 1, 3, 8, 40), datetime.datetime(2015, 1, 3, 13, 40)), ('DCA', datetime.datetime(2015, 1, 4, 15, 15), datetime.datetime(2015, 1, 4, 18, 5)), ('JAX', datetime.datetime(2015, 1, 5, 10, 20), datetime.datetime(2015, 1, 5, 12, 30)), ('FLL', datetime.datetime(2015, 1, 5, 7, 5), datetime.datetime(2015, 1, 5, 8, 23)), ('LAS', datetime.datetime(2015, 1, 4, 22, 49), datetime.datetime(2015, 1, 5, 6, 6))]
#
# ANT REACHED DESTINATION
#
# travel cost: 333.78999999999996
# connections number: 2
# flights:
#  ['LAS', ('DFW', datetime.datetime(2015, 1, 4, 16, 40), datetime.datetime(2015, 1, 4, 21, 20)), ('JAX', datetime.datetime(2015, 1, 5, 8, 40), datetime.datetime(2015, 1, 5, 11, 55))]
#
# ANT REACHED DESTINATION
#
# travel cost: 667.0699999999999
# connections number: 4
# flights:
#  ['LAS', ('LAX', datetime.datetime(2015, 1, 5, 6, 0), datetime.datetime(2015, 1, 5, 7, 5)), ('MCI', datetime.datetime(2015, 1, 5, 8, 55), datetime.datetime(2015, 1, 5, 14, 0)), ('ORD', datetime.datetime(2015, 1, 5, 18, 27), datetime.datetime(2015, 1, 5, 20, 7)), ('JAX', datetime.datetime(2015, 1, 6, 8, 30), datetime.datetime(2015, 1, 6, 11, 49))]
#
# ANT REACHED DESTINATION
#
# travel cost: 1040.3500000000001
# connections number: 6
# flights:
#  ['LAS', ('TUS', datetime.datetime(2015, 1, 4, 8, 55), datetime.datetime(2015, 1, 4, 11, 5)), ('LAX', datetime.datetime(2015, 1, 4, 13, 10), datetime.datetime(2015, 1, 4, 13, 45)), ('SAN', datetime.datetime(2015, 1, 4, 17, 5), datetime.datetime(2015, 1, 4, 17, 50)), ('SJC', datetime.datetime(2015, 1, 4, 20, 10), datetime.datetime(2015, 1, 4, 21, 30)), ('MDW', datetime.datetime(2015, 1, 5, 14, 15), datetime.datetime(2015, 1, 5, 20, 25)), ('JAX', datetime.datetime(2015, 1, 6, 14, 55), datetime.datetime(2015, 1, 6, 18, 10))]
#
# ANT REACHED DESTINATION
#
# travel cost: 624.27
# connections number: 4
# flights:
#  ['LAS', ('MIA', datetime.datetime(2015, 1, 3, 15, 0), datetime.datetime(2015, 1, 3, 22, 30)), ('ORF', datetime.datetime(2015, 1, 5, 9, 31), datetime.datetime(2015, 1, 5, 11, 52)), ('BWI', datetime.datetime(2015, 1, 5, 20, 15), datetime.datetime(2015, 1, 5, 21, 20)), ('JAX', datetime.datetime(2015, 1, 6, 16, 10), datetime.datetime(2015, 1, 6, 18, 20))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 441.55
# connections number: 6
# flights:
#  ['LAS', ('SAT', datetime.datetime(2015, 1, 2, 12, 10), datetime.datetime(2015, 1, 2, 16, 40)), ('SLC', datetime.datetime(2015, 1, 3, 14, 10), datetime.datetime(2015, 1, 3, 16, 11)), ('JFK', datetime.datetime(2015, 1, 3, 23, 59), datetime.datetime(2015, 1, 4, 6, 23)), ('JAX', datetime.datetime(2015, 1, 4, 14, 59), datetime.datetime(2015, 1, 4, 17, 47)), ('DTW', datetime.datetime(2015, 1, 3, 13, 55), datetime.datetime(2015, 1, 3, 16, 19)), ('LAS', datetime.datetime(2015, 1, 3, 6, 0), datetime.datetime(2015, 1, 3, 12, 53))]
#
# ant died :c
#
# travel cost: 0
# connections number: 0
# flights:
#  ['LAS']
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 740.3399999999999
# connections number: 6
# flights:
#  ['LAS', ('LGB', datetime.datetime(2015, 1, 4, 7, 5), datetime.datetime(2015, 1, 4, 8, 10)), ('SLC', datetime.datetime(2015, 1, 4, 13, 5), datetime.datetime(2015, 1, 4, 15, 54)), ('ATL', datetime.datetime(2015, 1, 4, 23, 55), datetime.datetime(2015, 1, 5, 5, 20)), ('JAX', datetime.datetime(2015, 1, 5, 8, 10), datetime.datetime(2015, 1, 5, 9, 16)), ('JFK', datetime.datetime(2015, 1, 4, 20, 30), datetime.datetime(2015, 1, 4, 23, 10)), ('LAS', datetime.datetime(2015, 1, 4, 13, 40), datetime.datetime(2015, 1, 4, 21, 30))]
#
# ANT REACHED DESTINATION
#
# travel cost: 287.35
# connections number: 2
# flights:
#  ['LAS', ('ATL', datetime.datetime(2015, 1, 6, 23, 30), datetime.datetime(2015, 1, 7, 6, 11)), ('JAX', datetime.datetime(2015, 1, 7, 8, 10), datetime.datetime(2015, 1, 7, 9, 16))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 444.97999999999996
# connections number: 8
# flights:
#  ['LAS', ('BLI', datetime.datetime(2015, 1, 1, 13, 15), datetime.datetime(2015, 1, 1, 16, 0)), ('HNL', datetime.datetime(2015, 1, 3, 17, 40), datetime.datetime(2015, 1, 3, 22, 12)), ('PHX', datetime.datetime(2015, 1, 3, 23, 50), datetime.datetime(2015, 1, 4, 8, 40)), ('ABQ', datetime.datetime(2015, 1, 4, 10, 35), datetime.datetime(2015, 1, 4, 11, 40)), ('DFW', datetime.datetime(2015, 1, 5, 9, 0), datetime.datetime(2015, 1, 5, 11, 45)), ('JAX', datetime.datetime(2015, 1, 5, 14, 30), datetime.datetime(2015, 1, 5, 17, 45)), ('DCA', datetime.datetime(2015, 1, 5, 10, 20), datetime.datetime(2015, 1, 5, 12, 30)), ('LAS', datetime.datetime(2015, 1, 4, 13, 30), datetime.datetime(2015, 1, 4, 20, 50))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 670.96
# connections number: 5
# flights:
#  ['LAS', ('SAT', datetime.datetime(2015, 1, 3, 12, 10), datetime.datetime(2015, 1, 3, 16, 40)), ('BNA', datetime.datetime(2015, 1, 4, 9, 15), datetime.datetime(2015, 1, 4, 11, 15)), ('JAX', datetime.datetime(2015, 1, 4, 16, 30), datetime.datetime(2015, 1, 4, 18, 55)), ('IAD', datetime.datetime(2015, 1, 3, 12, 35), datetime.datetime(2015, 1, 3, 14, 43)), ('LAS', datetime.datetime(2015, 1, 2, 13, 43), datetime.datetime(2015, 1, 2, 21, 12))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 643.31
# connections number: 5
# flights:
#  ['LAS', ('MKE', datetime.datetime(2015, 1, 3, 13, 45), datetime.datetime(2015, 1, 3, 19, 10)), ('ORD', datetime.datetime(2015, 1, 4, 6, 33), datetime.datetime(2015, 1, 4, 7, 27)), ('JAX', datetime.datetime(2015, 1, 5, 7, 51), datetime.datetime(2015, 1, 5, 11, 14)), ('EWR', datetime.datetime(2015, 1, 4, 21, 0), datetime.datetime(2015, 1, 4, 23, 37)), ('LAS', datetime.datetime(2015, 1, 4, 10, 49), datetime.datetime(2015, 1, 4, 18, 45))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 681.59
# connections number: 11
# flights:
#  ['LAS', ('TUS', datetime.datetime(2015, 1, 2, 8, 50), datetime.datetime(2015, 1, 2, 11, 0)), ('LAX', datetime.datetime(2015, 1, 2, 14, 35), datetime.datetime(2015, 1, 2, 15, 10)), ('OAK', datetime.datetime(2015, 1, 2, 19, 20), datetime.datetime(2015, 1, 2, 20, 35)), ('SLC', datetime.datetime(2015, 1, 3, 8, 55), datetime.datetime(2015, 1, 3, 11, 35)), ('LWS', datetime.datetime(2015, 1, 3, 21, 57), datetime.datetime(2015, 1, 3, 22, 44)), ('SLC', datetime.datetime(2015, 1, 4, 12, 10), datetime.datetime(2015, 1, 4, 14, 38)), ('PHX', datetime.datetime(2015, 1, 4, 17, 35), datetime.datetime(2015, 1, 4, 19, 10)), ('DTW', datetime.datetime(2015, 1, 5, 0, 40), datetime.datetime(2015, 1, 5, 6, 20)), ('JAX', datetime.datetime(2015, 1, 5, 15, 46), datetime.datetime(2015, 1, 5, 18, 11)), ('IAH', datetime.datetime(2015, 1, 5, 10, 16), datetime.datetime(2015, 1, 5, 13, 19)), ('LAS', datetime.datetime(2015, 1, 5, 1, 44), datetime.datetime(2015, 1, 5, 6, 34))]
#
# ant died :c
#
# travel cost: 0
# connections number: 0
# flights:
#  ['LAS']
#
# ANT REACHED DESTINATION
#
# travel cost: 743.1500000000001
# connections number: 3
# flights:
#  ['LAS', ('PIT', datetime.datetime(2015, 1, 5, 9, 55), datetime.datetime(2015, 1, 5, 17, 0)), ('DFW', datetime.datetime(2015, 1, 6, 9, 0), datetime.datetime(2015, 1, 6, 11, 25)), ('JAX', datetime.datetime(2015, 1, 6, 14, 30), datetime.datetime(2015, 1, 6, 17, 41))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 492.17999999999995
# connections number: 4
# flights:
#  ['LAS', ('DEN', datetime.datetime(2015, 1, 5, 6, 45), datetime.datetime(2015, 1, 5, 9, 34)), ('JAX', datetime.datetime(2015, 1, 5, 17, 45), datetime.datetime(2015, 1, 5, 22, 50)), ('BOS', datetime.datetime(2015, 1, 5, 8, 47), datetime.datetime(2015, 1, 5, 11, 49)), ('LAS', datetime.datetime(2015, 1, 4, 23, 59), datetime.datetime(2015, 1, 5, 7, 49))]
#
# ANT REACHED DESTINATION
#
# travel cost: 518.3
# connections number: 5
# flights:
#  ['LAS', ('SAN', datetime.datetime(2015, 1, 1, 9, 35), datetime.datetime(2015, 1, 1, 10, 40)), ('ABQ', datetime.datetime(2015, 1, 1, 20, 40), datetime.datetime(2015, 1, 1, 23, 20)), ('DAL', datetime.datetime(2015, 1, 2, 6, 15), datetime.datetime(2015, 1, 2, 9, 0)), ('HOU', datetime.datetime(2015, 1, 2, 12, 0), datetime.datetime(2015, 1, 2, 13, 5)), ('JAX', datetime.datetime(2015, 1, 2, 20, 5), datetime.datetime(2015, 1, 2, 23, 0))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 472.27
# connections number: 4
# flights:
#  ['LAS', ('BNA', datetime.datetime(2015, 1, 3, 15, 10), datetime.datetime(2015, 1, 3, 20, 35)), ('JAX', datetime.datetime(2015, 1, 4, 8, 5), datetime.datetime(2015, 1, 4, 10, 30)), ('DEN', datetime.datetime(2015, 1, 2, 17, 45), datetime.datetime(2015, 1, 2, 22, 50)), ('LAS', datetime.datetime(2015, 1, 2, 17, 25), datetime.datetime(2015, 1, 2, 20, 17))]
#
# ant died :c
#
# travel cost: 74.47
# connections number: 1
# flights:
#  ['LAS', ('SLC', datetime.datetime(2015, 1, 7, 8, 0), datetime.datetime(2015, 1, 7, 10, 22))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 472.27
# connections number: 6
# flights:
#  ['LAS', ('MIA', datetime.datetime(2015, 1, 3, 0, 35), datetime.datetime(2015, 1, 3, 8, 3)), ('CVG', datetime.datetime(2015, 1, 3, 9, 34), datetime.datetime(2015, 1, 3, 12, 17)), ('ORD', datetime.datetime(2015, 1, 3, 19, 5), datetime.datetime(2015, 1, 3, 19, 22)), ('JAX', datetime.datetime(2015, 1, 4, 7, 51), datetime.datetime(2015, 1, 4, 11, 14)), ('DEN', datetime.datetime(2015, 1, 2, 17, 45), datetime.datetime(2015, 1, 2, 22, 50)), ('LAS', datetime.datetime(2015, 1, 2, 17, 25), datetime.datetime(2015, 1, 2, 20, 17))]
#
# ant died :c
#
# travel cost: 186.85
# connections number: 3
# flights:
#  ['LAS', ('RNO', datetime.datetime(2015, 1, 6, 20, 55), datetime.datetime(2015, 1, 6, 22, 15)), ('SLC', datetime.datetime(2015, 1, 7, 6, 25), datetime.datetime(2015, 1, 7, 9, 4)), ('VEL', datetime.datetime(2015, 1, 7, 11, 6), datetime.datetime(2015, 1, 7, 11, 59))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 904.92
# connections number: 7
# flights:
#  ['LAS', ('SMF', datetime.datetime(2015, 1, 4, 7, 30), datetime.datetime(2015, 1, 4, 8, 55)), ('PDX', datetime.datetime(2015, 1, 4, 10, 45), datetime.datetime(2015, 1, 4, 12, 15)), ('SFO', datetime.datetime(2015, 1, 4, 18, 55), datetime.datetime(2015, 1, 4, 20, 51)), ('DTW', datetime.datetime(2015, 1, 4, 22, 55), datetime.datetime(2015, 1, 5, 6, 27)), ('JAX', datetime.datetime(2015, 1, 5, 15, 46), datetime.datetime(2015, 1, 5, 18, 11)), ('FLL', datetime.datetime(2015, 1, 5, 7, 5), datetime.datetime(2015, 1, 5, 8, 23)), ('LAS', datetime.datetime(2015, 1, 4, 22, 49), datetime.datetime(2015, 1, 5, 6, 6))]
#
# ANT REACHED DESTINATION
#
# travel cost: 709.01
# connections number: 3
# flights:
#  ['LAS', ('SEA', datetime.datetime(2015, 1, 5, 15, 0), datetime.datetime(2015, 1, 5, 17, 45)), ('DFW', datetime.datetime(2015, 1, 5, 23, 50), datetime.datetime(2015, 1, 6, 5, 30)), ('JAX', datetime.datetime(2015, 1, 6, 8, 30), datetime.datetime(2015, 1, 6, 11, 40))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 696.96
# connections number: 4
# flights:
#  ['LAS', ('FLL', datetime.datetime(2015, 1, 4, 15, 20), datetime.datetime(2015, 1, 4, 22, 50)), ('JAX', datetime.datetime(2015, 1, 5, 19, 45), datetime.datetime(2015, 1, 5, 21, 3)), ('IAD', datetime.datetime(2015, 1, 5, 12, 35), datetime.datetime(2015, 1, 5, 14, 43)), ('LAS', datetime.datetime(2015, 1, 4, 22, 55), datetime.datetime(2015, 1, 5, 6, 15))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 643.31
# connections number: 6
# flights:
#  ['LAS', ('LGB', datetime.datetime(2015, 1, 4, 7, 5), datetime.datetime(2015, 1, 4, 8, 10)), ('SFO', datetime.datetime(2015, 1, 4, 20, 31), datetime.datetime(2015, 1, 4, 21, 56)), ('IAH', datetime.datetime(2015, 1, 5, 0, 45), datetime.datetime(2015, 1, 5, 6, 17)), ('JAX', datetime.datetime(2015, 1, 5, 10, 16), datetime.datetime(2015, 1, 5, 13, 19)), ('EWR', datetime.datetime(2015, 1, 4, 21, 0), datetime.datetime(2015, 1, 4, 23, 37)), ('LAS', datetime.datetime(2015, 1, 4, 10, 49), datetime.datetime(2015, 1, 4, 18, 45))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 503.94
# connections number: 5
# flights:
#  ['LAS', ('DEN', datetime.datetime(2015, 1, 3, 6, 15), datetime.datetime(2015, 1, 3, 9, 12)), ('JAX', datetime.datetime(2015, 1, 3, 17, 45), datetime.datetime(2015, 1, 3, 22, 50)), ('LGA', datetime.datetime(2015, 1, 3, 9, 40), datetime.datetime(2015, 1, 3, 12, 26)), ('ORD', datetime.datetime(2015, 1, 3, 5, 56), datetime.datetime(2015, 1, 3, 9, 0)), ('LAS', datetime.datetime(2015, 1, 3, 1, 10), datetime.datetime(2015, 1, 3, 6, 45))]
#
# ANT REACHED DESTINATION
#
# travel cost: 546.01
# connections number: 2
# flights:
#  ['LAS', ('DEN', datetime.datetime(2015, 1, 4, 6, 45), datetime.datetime(2015, 1, 4, 9, 34)), ('JAX', datetime.datetime(2015, 1, 4, 17, 45), datetime.datetime(2015, 1, 4, 22, 50))]
#
# ANT REACHED DESTINATION
#
# travel cost: 1544.8700000000001
# connections number: 11
# flights:
#  ['LAS', ('SAT', datetime.datetime(2015, 1, 1, 13, 50), datetime.datetime(2015, 1, 1, 18, 25)), ('LAX', datetime.datetime(2015, 1, 2, 6, 0), datetime.datetime(2015, 1, 2, 7, 27)), ('CLD', datetime.datetime(2015, 1, 2, 14, 32), datetime.datetime(2015, 1, 2, 15, 17)), ('LAX', datetime.datetime(2015, 1, 2, 20, 45), datetime.datetime(2015, 1, 2, 21, 28)), ('CLD', datetime.datetime(2015, 1, 3, 10, 0), datetime.datetime(2015, 1, 3, 10, 45)), ('LAX', datetime.datetime(2015, 1, 3, 13, 37), datetime.datetime(2015, 1, 3, 14, 20)), ('SLC', datetime.datetime(2015, 1, 3, 17, 30), datetime.datetime(2015, 1, 3, 20, 24)), ('MCO', datetime.datetime(2015, 1, 4, 10, 30), datetime.datetime(2015, 1, 4, 16, 49)), ('RIC', datetime.datetime(2015, 1, 5, 19, 40), datetime.datetime(2015, 1, 5, 21, 25)), ('ATL', datetime.datetime(2015, 1, 6, 7, 5), datetime.datetime(2015, 1, 6, 9, 5)), ('JAX', datetime.datetime(2015, 1, 6, 10, 50), datetime.datetime(2015, 1, 6, 12, 10))]
#
# ANT REACHED DESTINATION
#
# travel cost: 647.84
# connections number: 3
# flights:
#  ['LAS', ('MCO', datetime.datetime(2015, 1, 5, 16, 15), datetime.datetime(2015, 1, 5, 23, 30)), ('EWR', datetime.datetime(2015, 1, 6, 6, 57), datetime.datetime(2015, 1, 6, 9, 30)), ('JAX', datetime.datetime(2015, 1, 6, 15, 28), datetime.datetime(2015, 1, 6, 18, 8))]
#
# ant died :c
#
# travel cost: 125.47
# connections number: 1
# flights:
#  ['LAS', ('DFW', datetime.datetime(2015, 1, 7, 9, 7), datetime.datetime(2015, 1, 7, 13, 50))]
#
# ANT REACHED DESTINATION
#
# travel cost: 700.86
# connections number: 3
# flights:
#  ['LAS', ('MCO', datetime.datetime(2015, 1, 5, 16, 15), datetime.datetime(2015, 1, 5, 23, 30)), ('BOS', datetime.datetime(2015, 1, 6, 7, 20), datetime.datetime(2015, 1, 6, 10, 8)), ('JAX', datetime.datetime(2015, 1, 6, 13, 40), datetime.datetime(2015, 1, 6, 16, 42))]
#
# ANT REACHED DESTINATION
#
# travel cost: 834.56
# connections number: 7
# flights:
#  ['LAS', ('OAK', datetime.datetime(2015, 1, 4, 10, 10), datetime.datetime(2015, 1, 4, 11, 40)), ('LAS', datetime.datetime(2015, 1, 4, 13, 50), datetime.datetime(2015, 1, 4, 15, 15)), ('ONT', datetime.datetime(2015, 1, 5, 8, 0), datetime.datetime(2015, 1, 5, 8, 55)), ('SMF', datetime.datetime(2015, 1, 5, 15, 40), datetime.datetime(2015, 1, 5, 16, 55)), ('SNA', datetime.datetime(2015, 1, 5, 21, 5), datetime.datetime(2015, 1, 5, 22, 25)), ('DEN', datetime.datetime(2015, 1, 6, 6, 45), datetime.datetime(2015, 1, 6, 10, 15)), ('JAX', datetime.datetime(2015, 1, 6, 13, 55), datetime.datetime(2015, 1, 6, 19, 0))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 492.91
# connections number: 4
# flights:
#  ['LAS', ('DEN', datetime.datetime(2015, 1, 5, 5, 50), datetime.datetime(2015, 1, 5, 8, 45)), ('JAX', datetime.datetime(2015, 1, 5, 17, 45), datetime.datetime(2015, 1, 5, 22, 50)), ('DFW', datetime.datetime(2015, 1, 5, 11, 15), datetime.datetime(2015, 1, 5, 14, 25)), ('LAS', datetime.datetime(2015, 1, 5, 8, 5), datetime.datetime(2015, 1, 5, 12, 45))]
#
# ANT REACHED DESTINATION
#
# travel cost: 513.75
# connections number: 2
# flights:
#  ['LAS', ('DEN', datetime.datetime(2015, 1, 6, 7, 50), datetime.datetime(2015, 1, 6, 10, 40)), ('JAX', datetime.datetime(2015, 1, 6, 13, 55), datetime.datetime(2015, 1, 6, 19, 0))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 444.97999999999996
# connections number: 9
# flights:
#  ['LAS', ('ELP', datetime.datetime(2015, 1, 1, 9, 50), datetime.datetime(2015, 1, 1, 12, 25)), ('SAT', datetime.datetime(2015, 1, 2, 7, 5), datetime.datetime(2015, 1, 2, 9, 25)), ('SFO', datetime.datetime(2015, 1, 2, 20, 6), datetime.datetime(2015, 1, 2, 22, 7)), ('SLC', datetime.datetime(2015, 1, 3, 11, 55), datetime.datetime(2015, 1, 3, 14, 47)), ('PSC', datetime.datetime(2015, 1, 4, 11, 22), datetime.datetime(2015, 1, 4, 12, 17)), ('DEN', datetime.datetime(2015, 1, 4, 18, 4), datetime.datetime(2015, 1, 4, 21, 14)), ('JAX', datetime.datetime(2015, 1, 5, 17, 45), datetime.datetime(2015, 1, 5, 22, 50)), ('DCA', datetime.datetime(2015, 1, 5, 10, 20), datetime.datetime(2015, 1, 5, 12, 30)), ('LAS', datetime.datetime(2015, 1, 4, 13, 30), datetime.datetime(2015, 1, 4, 20, 50))]
#
# ANT REACHED DESTINATION
#
# travel cost: 763.1500000000001
# connections number: 5
# flights:
#  ['LAS', ('RNO', datetime.datetime(2015, 1, 5, 9, 55), datetime.datetime(2015, 1, 5, 11, 15)), ('SLC', datetime.datetime(2015, 1, 5, 17, 59), datetime.datetime(2015, 1, 5, 20, 27)), ('MCO', datetime.datetime(2015, 1, 5, 23, 59), datetime.datetime(2015, 1, 6, 6, 13)), ('HOU', datetime.datetime(2015, 1, 6, 11, 15), datetime.datetime(2015, 1, 6, 12, 55)), ('JAX', datetime.datetime(2015, 1, 7, 10, 40), datetime.datetime(2015, 1, 7, 13, 35))]
#
# ANT REACHED DESTINATION
#
# travel cost: 818.8
# connections number: 4
# flights:
#  ['LAS', ('PHX', datetime.datetime(2015, 1, 4, 7, 15), datetime.datetime(2015, 1, 4, 9, 25)), ('BUF', datetime.datetime(2015, 1, 4, 17, 35), datetime.datetime(2015, 1, 4, 23, 35)), ('JFK', datetime.datetime(2015, 1, 5, 5, 35), datetime.datetime(2015, 1, 5, 7, 3)), ('JAX', datetime.datetime(2015, 1, 5, 14, 59), datetime.datetime(2015, 1, 5, 17, 47))]
#
# ANT REACHED DESTINATION
#
# travel cost: 1342.8200000000002
# ...
#
# ant died :c
#
# travel cost: 210.53
# connections number: 2
# flights:
#  ['LAS', ('TUS', datetime.datetime(2015, 1, 7, 6, 40), datetime.datetime(2015, 1, 7, 8, 50)), ('DEN', datetime.datetime(2015, 1, 7, 10, 30), datetime.datetime(2015, 1, 7, 12, 27))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 480.89
# connections number: 4
# flights:
#  ['LAS', ('IAH', datetime.datetime(2015, 1, 4, 1, 44), datetime.datetime(2015, 1, 4, 6, 34)), ('JAX', datetime.datetime(2015, 1, 4, 10, 16), datetime.datetime(2015, 1, 4, 13, 19)), ('ATL', datetime.datetime(2015, 1, 4, 8, 45), datetime.datetime(2015, 1, 4, 10, 0)), ('LAS', datetime.datetime(2015, 1, 3, 22, 30), datetime.datetime(2015, 1, 4, 5, 11))]
#
# ant died :c
#
# travel cost: 340.42
# connections number: 2
# flights:
#  ['LAS', ('IAD', datetime.datetime(2015, 1, 6, 13, 23), datetime.datetime(2015, 1, 6, 20, 50)), ('PIT', datetime.datetime(2015, 1, 7, 8, 37), datetime.datetime(2015, 1, 7, 9, 39))]
#
# ANT REACHED DESTINATION
#
# travel cost: 311.77
# connections number: 2
# flights:
#  ['LAS', ('MSP', datetime.datetime(2015, 1, 2, 13, 33), datetime.datetime(2015, 1, 2, 18, 45)), ('JAX', datetime.datetime(2015, 1, 3, 19, 40), datetime.datetime(2015, 1, 3, 23, 35))]
#
# ANT REACHED DESTINATION
#
# travel cost: 401.61
# connections number: 2
# flights:
#  ['LAS', ('CLT', datetime.datetime(2015, 1, 6, 23, 5), datetime.datetime(2015, 1, 7, 6, 5)), ('JAX', datetime.datetime(2015, 1, 7, 10, 5), datetime.datetime(2015, 1, 7, 11, 34))]
#
# ANT REACHED DESTINATION
#
# travel cost: 342.12
# connections number: 3
# flights:
#  ['LAS', ('ICT', datetime.datetime(2015, 1, 5, 10, 40), datetime.datetime(2015, 1, 5, 15, 5)), ('ATL', datetime.datetime(2015, 1, 5, 16, 40), datetime.datetime(2015, 1, 5, 19, 49)), ('JAX', datetime.datetime(2015, 1, 5, 22, 0), datetime.datetime(2015, 1, 5, 23, 8))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 402.17
# connections number: 9
# flights:
#  ['LAS', ('SDF', datetime.datetime(2015, 1, 3, 17, 5), datetime.datetime(2015, 1, 3, 23, 35)), ('MCO', datetime.datetime(2015, 1, 4, 14, 40), datetime.datetime(2015, 1, 4, 16, 40)), ('ISP', datetime.datetime(2015, 1, 5, 10, 20), datetime.datetime(2015, 1, 5, 12, 45)), ('TPA', datetime.datetime(2015, 1, 6, 6, 0), datetime.datetime(2015, 1, 6, 9, 15)), ('MHT', datetime.datetime(2015, 1, 6, 12, 45), datetime.datetime(2015, 1, 6, 15, 35)), ('BWI', datetime.datetime(2015, 1, 6, 17, 15), datetime.datetime(2015, 1, 6, 18, 50)), ('JAX', datetime.datetime(2015, 1, 7, 8, 35), datetime.datetime(2015, 1, 7, 10, 45)), ('CLT', datetime.datetime(2015, 1, 6, 20, 0), datetime.datetime(2015, 1, 6, 21, 18)), ('LAS', datetime.datetime(2015, 1, 6, 11, 35), datetime.datetime(2015, 1, 6, 18, 46))]
#
# ANT REACHED DESTINATION
#
# travel cost: 358.77
# connections number: 2
# flights:
#  ['LAS', ('DFW', datetime.datetime(2015, 1, 3, 1, 3), datetime.datetime(2015, 1, 3, 5, 30)), ('JAX', datetime.datetime(2015, 1, 3, 8, 40), datetime.datetime(2015, 1, 3, 11, 55))]
#
# ANT REACHED DESTINATION
#
# travel cost: 971.9300000000001
# connections number: 3
# flights:
#  ['LAS', ('CLE', datetime.datetime(2015, 1, 1, 22, 40), datetime.datetime(2015, 1, 2, 5, 40)), ('DEN', datetime.datetime(2015, 1, 2, 8, 46), datetime.datetime(2015, 1, 2, 10, 20)), ('JAX', datetime.datetime(2015, 1, 2, 17, 45), datetime.datetime(2015, 1, 2, 22, 50))]
#
# ANT REACHED DESTINATION
#
# travel cost: 582.3
# connections number: 4
# flights:
#  ['LAS', ('SFO', datetime.datetime(2015, 1, 3, 17, 5), datetime.datetime(2015, 1, 3, 18, 35)), ('LAX', datetime.datetime(2015, 1, 4, 6, 0), datetime.datetime(2015, 1, 4, 7, 27)), ('JFK', datetime.datetime(2015, 1, 4, 9, 0), datetime.datetime(2015, 1, 4, 17, 35)), ('JAX', datetime.datetime(2015, 1, 5, 8, 0), datetime.datetime(2015, 1, 5, 10, 38))]
#
# ANT REACHED DESTINATION
#
# travel cost: 733.8399999999999
# connections number: 3
# flights:
#  ['LAS', ('LAX', datetime.datetime(2015, 1, 4, 7, 30), datetime.datetime(2015, 1, 4, 8, 35)), ('IAH', datetime.datetime(2015, 1, 4, 13, 45), datetime.datetime(2015, 1, 4, 18, 59)), ('JAX', datetime.datetime(2015, 1, 5, 10, 16), datetime.datetime(2015, 1, 5, 13, 19))]
#
# ANT REACHED DESTINATION
#
# travel cost: 321.65
# connections number: 2
# flights:
#  ['LAS', ('CLT', datetime.datetime(2015, 1, 1, 14, 15), datetime.datetime(2015, 1, 1, 21, 22)), ('JAX', datetime.datetime(2015, 1, 2, 10, 5), datetime.datetime(2015, 1, 2, 11, 33))]
#
# ANT REACHED DESTINATION
#
# travel cost: 672.39
# connections number: 2
# flights:
#  ['LAS', ('PHL', datetime.datetime(2015, 1, 6, 9, 0), datetime.datetime(2015, 1, 6, 16, 39)), ('JAX', datetime.datetime(2015, 1, 7, 7, 45), datetime.datetime(2015, 1, 7, 10, 15))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 740.3399999999999
# connections number: 5
# flights:
#  ['LAS', ('SEA', datetime.datetime(2015, 1, 5, 15, 0), datetime.datetime(2015, 1, 5, 17, 45)), ('DFW', datetime.datetime(2015, 1, 5, 23, 50), datetime.datetime(2015, 1, 6, 5, 30)), ('JAX', datetime.datetime(2015, 1, 6, 8, 30), datetime.datetime(2015, 1, 6, 11, 40)), ('JFK', datetime.datetime(2015, 1, 4, 20, 30), datetime.datetime(2015, 1, 4, 23, 10)), ('LAS', datetime.datetime(2015, 1, 4, 13, 40), datetime.datetime(2015, 1, 4, 21, 30))]
#
# ant died :c
#
# travel cost: 0
# connections number: 0
# flights:
#  ['LAS']
#
# ant died :c
#
# travel cost: 734.08
# connections number: 5
# flights:
#  ['LAS', ('LAX', datetime.datetime(2015, 1, 5, 20, 37), datetime.datetime(2015, 1, 5, 21, 49)), ('PHX', datetime.datetime(2015, 1, 6, 7, 0), datetime.datetime(2015, 1, 6, 9, 20)), ('MDW', datetime.datetime(2015, 1, 6, 12, 35), datetime.datetime(2015, 1, 6, 17, 0)), ('PIT', datetime.datetime(2015, 1, 7, 6, 5), datetime.datetime(2015, 1, 7, 8, 30)), ('IAD', datetime.datetime(2015, 1, 7, 10, 11), datetime.datetime(2015, 1, 7, 11, 18))]
#
# ANT REACHED DESTINATION
#
# travel cost: 567.47
# connections number: 2
# flights:
#  ['LAS', ('DTW', datetime.datetime(2015, 1, 5, 8, 30), datetime.datetime(2015, 1, 5, 15, 30)), ('JAX', datetime.datetime(2015, 1, 6, 15, 46), datetime.datetime(2015, 1, 6, 18, 11))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 520.41
# connections number: 6
# flights:
#  ['LAS', ('LAX', datetime.datetime(2015, 1, 5, 6, 0), datetime.datetime(2015, 1, 5, 7, 5)), ('MCI', datetime.datetime(2015, 1, 5, 8, 55), datetime.datetime(2015, 1, 5, 14, 0)), ('ORD', datetime.datetime(2015, 1, 5, 18, 27), datetime.datetime(2015, 1, 5, 20, 7)), ('JAX', datetime.datetime(2015, 1, 6, 8, 30), datetime.datetime(2015, 1, 6, 11, 49)), ('HOU', datetime.datetime(2015, 1, 4, 20, 5), datetime.datetime(2015, 1, 4, 23, 0)), ('LAS', datetime.datetime(2015, 1, 4, 15, 30), datetime.datetime(2015, 1, 4, 20, 25))]
#
# ant died :c
#
# travel cost: 0
# connections number: 0
# flights:
#  ['LAS']
#
# ANT REACHED DESTINATION
#
# travel cost: 282.52
# connections number: 2
# flights:
#  ['LAS', ('MDW', datetime.datetime(2015, 1, 6, 6, 50), datetime.datetime(2015, 1, 6, 12, 20)), ('JAX', datetime.datetime(2015, 1, 6, 14, 55), datetime.datetime(2015, 1, 6, 18, 10))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 472.63
# connections number: 5
# flights:
#  ['LAS', ('MCO', datetime.datetime(2015, 1, 5, 16, 15), datetime.datetime(2015, 1, 5, 23, 30)), ('EWR', datetime.datetime(2015, 1, 6, 6, 57), datetime.datetime(2015, 1, 6, 9, 30)), ('JAX', datetime.datetime(2015, 1, 6, 15, 28), datetime.datetime(2015, 1, 6, 18, 8)), ('BNA', datetime.datetime(2015, 1, 5, 8, 5), datetime.datetime(2015, 1, 5, 10, 30)), ('LAS', datetime.datetime(2015, 1, 4, 18, 45), datetime.datetime(2015, 1, 5, 0, 15))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 322.19
# connections number: 7
# flights:
#  ['LAS', ('LBB', datetime.datetime(2015, 1, 6, 10, 50), datetime.datetime(2015, 1, 6, 14, 45)), ('IAH', datetime.datetime(2015, 1, 6, 16, 41), datetime.datetime(2015, 1, 6, 18, 10)), ('DEN', datetime.datetime(2015, 1, 6, 21, 20), datetime.datetime(2015, 1, 6, 22, 57)), ('CLT', datetime.datetime(2015, 1, 7, 1, 20), datetime.datetime(2015, 1, 7, 6, 19)), ('JAX', datetime.datetime(2015, 1, 7, 10, 5), datetime.datetime(2015, 1, 7, 11, 34)), ('FLL', datetime.datetime(2015, 1, 6, 18, 55), datetime.datetime(2015, 1, 6, 20, 13)), ('LAS', datetime.datetime(2015, 1, 6, 9, 5), datetime.datetime(2015, 1, 6, 16, 40))]
#
# ANT REACHED DESTINATION
#
# travel cost: 686.97
# connections number: 4
# flights:
#  ['LAS', ('SFO', datetime.datetime(2015, 1, 2, 14, 40), datetime.datetime(2015, 1, 2, 16, 10)), ('SMF', datetime.datetime(2015, 1, 3, 7, 30), datetime.datetime(2015, 1, 3, 8, 18)), ('ATL', datetime.datetime(2015, 1, 3, 12, 51), datetime.datetime(2015, 1, 3, 20, 6)), ('JAX', datetime.datetime(2015, 1, 3, 22, 0), datetime.datetime(2015, 1, 3, 23, 10))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 405.77
# connections number: 4
# flights:
#  ['LAS', ('ORD', datetime.datetime(2015, 1, 5, 1, 10), datetime.datetime(2015, 1, 5, 6, 45)), ('JAX', datetime.datetime(2015, 1, 7, 8, 30), datetime.datetime(2015, 1, 7, 11, 49)), ('IAH', datetime.datetime(2015, 1, 6, 19, 0), datetime.datetime(2015, 1, 6, 21, 59)), ('LAS', datetime.datetime(2015, 1, 6, 15, 4), datetime.datetime(2015, 1, 6, 20, 6))]
#
# ANT REACHED DESTINATION
#
# travel cost: 643.69
# connections number: 2
# flights:
#  ['LAS', ('ORD', datetime.datetime(2015, 1, 6, 1, 10), datetime.datetime(2015, 1, 6, 6, 45)), ('JAX', datetime.datetime(2015, 1, 6, 8, 30), datetime.datetime(2015, 1, 6, 11, 49))]
#
# ant died :c
#
# travel cost: 188.57999999999998
# connections number: 3
# flights:
#  ['LAS', ('ONT', datetime.datetime(2015, 1, 6, 20, 10), datetime.datetime(2015, 1, 6, 21, 5)), ('PHX', datetime.datetime(2015, 1, 7, 6, 30), datetime.datetime(2015, 1, 7, 8, 45)), ('BOI', datetime.datetime(2015, 1, 7, 10, 37), datetime.datetime(2015, 1, 7, 12, 49))]
#
# ANT REACHED DESTINATION
#
# travel cost: 762.6899999999999
# connections number: 4
# flights:
#  ['LAS', ('GEG', datetime.datetime(2015, 1, 3, 9, 20), datetime.datetime(2015, 1, 3, 11, 45)), ('SEA', datetime.datetime(2015, 1, 4, 5, 0), datetime.datetime(2015, 1, 4, 6, 10)), ('BOS', datetime.datetime(2015, 1, 4, 14, 58), datetime.datetime(2015, 1, 4, 22, 59)), ('JAX', datetime.datetime(2015, 1, 5, 8, 47), datetime.datetime(2015, 1, 5, 11, 49))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 476.78
# connections number: 7
# flights:
#  ['LAS', ('MIA', datetime.datetime(2015, 1, 4, 0, 35), datetime.datetime(2015, 1, 4, 8, 3)), ('MCO', datetime.datetime(2015, 1, 4, 14, 10), datetime.datetime(2015, 1, 4, 15, 17)), ('ROC', datetime.datetime(2015, 1, 6, 9, 55), datetime.datetime(2015, 1, 6, 12, 35)), ('ATL', datetime.datetime(2015, 1, 7, 6, 0), datetime.datetime(2015, 1, 7, 8, 35)), ('JAX', datetime.datetime(2015, 1, 7, 10, 50), datetime.datetime(2015, 1, 7, 12, 10)), ('BNA', datetime.datetime(2015, 1, 6, 18, 0), datetime.datetime(2015, 1, 6, 20, 25)), ('LAS', datetime.datetime(2015, 1, 5, 18, 25), datetime.datetime(2015, 1, 5, 23, 55))]
#
# ANT REACHED DESTINATION
#
# travel cost: 440.9
# connections number: 2
# flights:
#  ['LAS', ('JFK', datetime.datetime(2015, 1, 3, 21, 10), datetime.datetime(2015, 1, 4, 4, 52)), ('JAX', datetime.datetime(2015, 1, 4, 8, 0), datetime.datetime(2015, 1, 4, 10, 38))]
#
# ANT REACHED DESTINATION
#
# travel cost: 463.6
# connections number: 3
# flights:
#  ['LAS', ('SAT', datetime.datetime(2015, 1, 2, 18, 15), datetime.datetime(2015, 1, 2, 22, 45)), ('DFW', datetime.datetime(2015, 1, 3, 5, 45), datetime.datetime(2015, 1, 3, 6, 50)), ('JAX', datetime.datetime(2015, 1, 3, 8, 40), datetime.datetime(2015, 1, 3, 11, 55))]
#
# ANT REACHED DESTINATION
#
# travel cost: 444.97999999999996
# connections number: 2
# flights:
#  ['LAS', ('DCA', datetime.datetime(2015, 1, 4, 13, 30), datetime.datetime(2015, 1, 4, 20, 50)), ('JAX', datetime.datetime(2015, 1, 5, 10, 20), datetime.datetime(2015, 1, 5, 12, 30))]
#
# ANT REACHED DESTINATION
#
# travel cost: 608.31
# connections number: 2
# flights:
#  ['LAS', ('BOS', datetime.datetime(2015, 1, 2, 23, 59), datetime.datetime(2015, 1, 3, 7, 49)), ('JAX', datetime.datetime(2015, 1, 3, 16, 25), datetime.datetime(2015, 1, 3, 19, 27))]
#
# ant died :c
#
# travel cost: 161.6
# connections number: 3
# flights:
#  ['LAS', ('SJC', datetime.datetime(2015, 1, 6, 19, 55), datetime.datetime(2015, 1, 6, 21, 25)), ('LAX', datetime.datetime(2015, 1, 7, 7, 5), datetime.datetime(2015, 1, 7, 8, 28)), ('SBA', datetime.datetime(2015, 1, 7, 10, 0), datetime.datetime(2015, 1, 7, 10, 46))]
#
# ANT REACHED DESTINATION
#
# travel cost: 755.27
# connections number: 2
# flights:
#  ['LAS', ('PHL', datetime.datetime(2015, 1, 5, 22, 35), datetime.datetime(2015, 1, 6, 6, 1)), ('JAX', datetime.datetime(2015, 1, 6, 7, 45), datetime.datetime(2015, 1, 6, 10, 15))]
#
# ANT REACHED DESTINATION
#
# travel cost: 735.54
# connections number: 3
# flights:
#  ['LAS', ('FNT', datetime.datetime(2015, 1, 5, 10, 20), datetime.datetime(2015, 1, 5, 17, 5)), ('ORD', datetime.datetime(2015, 1, 6, 5, 51), datetime.datetime(2015, 1, 6, 6, 10)), ('JAX', datetime.datetime(2015, 1, 6, 8, 30), datetime.datetime(2015, 1, 6, 11, 49))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 535.12
# connections number: 6
# flights:
#  ['LAS', ('MCO', datetime.datetime(2015, 1, 4, 16, 15), datetime.datetime(2015, 1, 4, 23, 30)), ('MIA', datetime.datetime(2015, 1, 5, 8, 30), datetime.datetime(2015, 1, 5, 9, 37)), ('CLT', datetime.datetime(2015, 1, 5, 14, 59), datetime.datetime(2015, 1, 5, 17, 5)), ('JAX', datetime.datetime(2015, 1, 5, 20, 0), datetime.datetime(2015, 1, 5, 21, 17)), ('BOS', datetime.datetime(2015, 1, 5, 13, 45), datetime.datetime(2015, 1, 5, 16, 47)), ('LAS', datetime.datetime(2015, 1, 4, 23, 59), datetime.datetime(2015, 1, 5, 7, 49))]
#
# ant died :c
#
# travel cost: 475.09000000000003
# connections number: 3
# flights:
#  ['LAS', ('SEA', datetime.datetime(2015, 1, 6, 12, 15), datetime.datetime(2015, 1, 6, 15, 1)), ('SJC', datetime.datetime(2015, 1, 6, 18, 15), datetime.datetime(2015, 1, 6, 20, 17)), ('SNA', datetime.datetime(2015, 1, 7, 9, 15), datetime.datetime(2015, 1, 7, 10, 30))]
#
# ANT REACHED DESTINATION
#
# travel cost: 424.9
# connections number: 2
# flights:
#  ['LAS', ('ORD', datetime.datetime(2015, 1, 5, 6, 45), datetime.datetime(2015, 1, 5, 12, 15)), ('JAX', datetime.datetime(2015, 1, 6, 8, 30), datetime.datetime(2015, 1, 6, 11, 49))]
#
# ANT REACHED DESTINATION AND CAME BACK
#
# travel cost: 420.85
# connections number: 4
# flights:
#  ['LAS', ('DFW', datetime.datetime(2015, 1, 4, 6, 0), datetime.datetime(2015, 1, 4, 10, 40)), ('JAX', datetime.datetime(2015, 1, 4, 14, 30), datetime.datetime(2015, 1, 4, 17, 45)), ('ATL', datetime.datetime(2015, 1, 4, 12, 15), datetime.datetime(2015, 1, 4, 13, 24)), ('LAS', datetime.datetime(2015, 1, 4, 0, 30), datetime.datetime(2015, 1, 4, 7, 11))]
#
# ant died :c
#
# travel cost: 112.61
# connections number: 1
# flights:
#  ['LAS', ('TPA', datetime.datetime(2015, 1, 7, 10, 0), datetime.datetime(2015, 1, 7, 17, 10))]
#
# ANT REACHED DESTINATION
#
# travel cost: 689.75
# connections number: 3
# flights:
#  ['LAS', ('SEA', datetime.datetime(2015, 1, 5, 6, 30), datetime.datetime(2015, 1, 5, 9, 13)), ('MDW', datetime.datetime(2015, 1, 5, 14, 25), datetime.datetime(2015, 1, 5, 20, 20)), ('JAX', datetime.datetime(2015, 1, 6, 14, 55), datetime.datetime(2015, 1, 6, 18, 10))]
#
# ANT REACHED DESTINATION
#
# travel cost: 553.21
# connections number: 3
# flights:
#  ['LAS', ('RNO', datetime.datetime(2015, 1, 3, 12, 50), datetime.datetime(2015, 1, 3, 14, 10)), ('DEN', datetime.datetime(2015, 1, 4, 6, 0), datetime.datetime(2015, 1, 4, 9, 10)), ('JAX', datetime.datetime(2015, 1, 4, 17, 45), datetime.datetime(2015, 1, 4, 22, 50))]
#
# ant died :c
#
# travel cost: 752.11
# connections number: 2
# flights:
#  ['LAS', ('FLL', datetime.datetime(2015, 1, 6, 22, 44), datetime.datetime(2015, 1, 7, 6, 1)), ('ORD', datetime.datetime(2015, 1, 7, 7, 40), datetime.datetime(2015, 1, 7, 9, 57))]
#
# ANT REACHED DESTINATION
#
# travel cost: 560.51
# connections number: 3
# flights:
#  ['LAS', ('SJC', datetime.datetime(2015, 1, 3, 17, 40), datetime.datetime(2015, 1, 3, 19, 5)), ('DFW', datetime.datetime(2015, 1, 4, 6, 20), datetime.datetime(2015, 1, 4, 11, 55)), ('JAX', datetime.datetime(2015, 1, 4, 18, 45), datetime.datetime(2015, 1, 4, 21, 55))]
#
# DONE
